# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import pickle
import gensim.downloader as api
from gensim.models import KeyedVectors

# %% [markdown]
# # Dataset

# %%
train_df = pd.read_csv('/kaggle/input/nli-data/new_train_all.csv',index_col=0)
train_df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                                                   premise  \
# 9604.0  If Emily passes her driving test, her best fri...
# 9605.0  It's not the case that if Emily passes her dri...
# 9606.0  Sam believes that if Emily passes her driving ...
# 9607.0  Is it true that if Emily passes her driving te...
# 9608.0  If Scarlett finishes her work early, her husba...
# ...                                                   ...
# NaN     If Emily passes her driving test, her best fri...
# NaN     It's not the case that if Scarlett finishes he...
# NaN     Sam believes that if Chloe finishes his work e...
# NaN     Is it true that if Ryan passes his driving tes...
# NaN     If Ryan passes his driving test, his parents w...
#
#                            hypothesis gold_label              type
# 9604.0       Emily has a best friend.          E  type5_possessive
# 9605.0       Emily has a best friend.          E  type5_possessive
# 9606.0       Emily has a best friend.          E  type5_possessive
# 9607.0       Emily has a best friend.          E  type5_possessive
# 9608.0        Scarlett has a husband.          E  type5_possessive
# ...                               ...        ...               ...
# NaN               Emily has a sister.          N  type5_possessive
# NaN     Scarlett has a sister-in-law.          N  type5_possessive
# NaN                 Chloe has a boss.          N  type5_possessive
# NaN                Ryan has siblings.          N  type5_possessive
# NaN        Ryan does not have parents          C  type5_possessive
#
# [6486 rows x 4 columns]

# %%
valid_df = pd.read_csv('/kaggle/input/nli-data/new_valid_all.csv',index_col=0)
valid_df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                                                   premise  \
# 9600.0  If Jessica attends the conference, her colleag...
# 9601.0  It's not the case that if Jessica attends the ...
# 9602.0  Sam believes that if Jessica attends the confe...
# 9603.0  Is it true that if Jessica attends the confere...
# 9620.0  If Mia's car breaks down, her coworker will gi...
# ...                                                   ...
# NaN     If Margaret graduates from college, her parent...
# NaN     It's not the case that if Margaret graduates f...
# NaN     Sam believes that if Margaret graduates from c...
# NaN     Is it true that if Margaret graduates from col...
# NaN     If Margaret graduates from college, her parent...
#
#                                                hypothesis gold_label  \
# 9600.0                           Jessica has a colleague.          E
# 9601.0                           Jessica has a colleague.          E
# 9602.0                           Jessica has a colleague.          E
# 9603.0                           Jessica has a colleague.          E
# 9620.0                                Mia has a coworker.          E
# ...                                                   ...        ...
# NaN                                Margaret has siblings.          N
# NaN                                Margaret has siblings.          N
# NaN                                Margaret has siblings.          N
# NaN                                Margaret has siblings.          N
# NaN     Margaret has graduated from college, but her p...          C
#
#                     type
# 9600.0  type5_possessive
# 9601.0  type5_possessive
# 9602.0  type5_possessive
# 9603.0  type5_possessive
# 9620.0  type5_possessive
# ...                  ...
# NaN     type5_possessive
# NaN     type5_possessive
# NaN     type5_possessive
# NaN     type5_possessive
# NaN     type5_possessive
#
# [2348 rows x 4 columns]

# %%
test_df = pd.read_csv('/kaggle/input/nli-data/new_test_all.csv',index_col=0)
test_df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                                                   premise  \
# 9616.0  If Charlotte passes her driving test, her pare...
# 9617.0  It's not the case that if Charlotte passes her...
# 9618.0  Sam believes that if Charlotte passes her driv...
# 9619.0  Is it true that if Charlotte passes her drivin...
# 9628.0  If Lily takes the train to the city, her frien...
# ...                                                   ...
# NaN     If Sophia decides to attend the concert, his b...
# NaN     It's not the case that if Sophia decides to at...
# NaN     Sam believes that if Sophia decides to attend ...
# NaN     Is it true that if Sophia decides to attend th...
# NaN     If Sophia decides to attend the concert, his b...
#
#                                                hypothesis gold_label  \
# 9616.0                             Charlotte has parents.          E
# 9617.0                             Charlotte has parents.          E
# 9618.0                             Charlotte has parents.          E
# 9619.0                             Charlotte has parents.          E
# 9628.0                                 Lily has a friend.          E
# ...                                                   ...        ...
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN     Sophia has decided to attend the concert, but ...          C
#
#                     type
# 9616.0  type5_possessive
# 9617.0  type5_possessive
# 9618.0  type5_possessive
# 9619.0  type5_possessive
# 9628.0  type5_possessive
# ...                  ...
# NaN     type5_possessive
# NaN     type5_possessive
# NaN     type5_possessive
# NaN     type5_possessive
# NaN     type5_possessive
#
# [2367 rows x 4 columns]

# %%
train_df['premise'].isna().sum()
# Out:
# 0

# %%
train_df['hypothesis'].isna().sum()
# Out:
# 0

# %%
train_df[train_df['hypothesis'].isna()]
# Out:
# Empty DataFrame
# Columns: [premise, hypothesis, gold_label, type]
# Index: []

# %%
train_df.loc[train_df['hypothesis'].isna(), 'hypothesis'] = "Martin has incited a response before"

# %%
train_df[train_df['hypothesis'].isna()]
# Out:
# Empty DataFrame
# Columns: [premise, hypothesis, gold_label, type]
# Index: []

# %%
train_df['gold_label'].value_counts()
# Out:
# gold_label
# C    2172
# N    2162
# E    2152
# Name: count, dtype: int64

# %%
def encode_infersent_sentence(sentence,model):
    return model.encode([sentence], tokenize=True)[0]

# %%
def get_sentence_embedding(row, model, glove):
    premise = row['premise']
    hypothesis = row['hypothesis'] 
    if glove:
        embedded_premise = encode_glove_sentence(premise,model)
        embedded_hypothesis = encode_glove_sentence(hypothesis,model)
    else:
        embedded_premise = encode_infersent_sentence(premise,model)
        embedded_hypothesis = encode_infersent_sentence(hypothesis,model)
    return np.concatenate((embedded_premise, embedded_hypothesis), axis=0)

# %% [markdown]
# # InferSent

# %%
import sys

# %%
sys.path.append('/kaggle/input/infersent')

# %%
from models import InferSent
import torch

# %%
params_model = {
    'bsize': 64,
    'word_emb_dim': 300,
    'enc_lstm_dim': 2048,
    'pool_type': 'max',
    'dpout_model': 0.0,
    'n_enc_layers': 1,
    'version': 2  # Use version 2 for fastText
}

# %%
infersent = InferSent(params_model)
infersent.load_state_dict(torch.load('/kaggle/input/infersent/infersent2.pkl'))
infersent.set_w2v_path('/kaggle/input/infersent/crawl-300d-2M.vec/crawl-300d-2M.vec')
# Out:
# <ipython-input-16-6d0716483458>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   infersent.load_state_dict(torch.load('/kaggle/input/infersent/infersent2.pkl'))

# %%
premises = train_df['premise'].tolist()
hypotheses = train_df['hypothesis'].tolist()
all_sentences = premises + hypotheses
len(all_sentences)
# Out:
# 12972

# %%
infersent.build_vocab(all_sentences, tokenize=True)
# Out:
# Found 3358(/3376) words with w2v vectors
# Vocab size : 3358

# %%
train_df = pd.read_csv('/kaggle/working/new_train_data_embeddings.csv')
train_df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#       Unnamed: 0                                            premise  \
# 0         9604.0  If Emily passes her driving test, her best fri...
# 1         9605.0  It's not the case that if Emily passes her dri...
# 2         9606.0  Sam believes that if Emily passes her driving ...
# 3         9607.0  Is it true that if Emily passes her driving te...
# 4         9608.0  If Scarlett finishes her work early, her husba...
# ...          ...                                                ...
# 6481         NaN  If Emily passes her driving test, her best fri...
# 6482         NaN  It's not the case that if Scarlett finishes he...
# 6483         NaN  Sam believes that if Chloe finishes his work e...
# 6484         NaN  Is it true that if Ryan passes his driving tes...
# 6485         NaN  If Ryan passes his driving test, his parents w...
#
#                          hypothesis gold_label              type  \
# 0          Emily has a best friend.          E  type5_possessive
# 1          Emily has a best friend.          E  type5_possessive
# 2          Emily has a best friend.          E  type5_possessive
# 3          Emily has a best friend.          E  type5_possessive
# 4           Scarlett has a husband.          E  type5_possessive
# ...                             ...        ...               ...
# 6481            Emily has a sister.          N  type5_possessive
# 6482  Scarlett has a sister-in-law.          N  type5_possessive
# 6483              Chloe has a boss.          N  type5_possessive
# 6484             Ryan has siblings.          N  type5_possessive
# 6485     Ryan does not have parents          C  type5_possessive
#
#                                         glove_embedding  \
# 0     [ 6.90574646e-02  3.88652146e-01 -1.84048399e-...
# 1     [ 2.19390422e-01  2.52608240e-01 -1.42022654e-...
# 2     [ 1.56875432e-01  3.00709426e-01 -1.08546570e-...
# 3     [ 1.88888073e-01  3.07597548e-01 -1.27724648e-...
# 4     [ 2.48616010e-01  3.86440784e-01 -2.13514715e-...
# ...                                                 ...
# 6481  [ 6.90574646e-02  3.88652146e-01 -1.84048399e-...
# 6482  [ 3.69162679e-01  2.23925188e-01 -1.53261706e-...
# 6483  [ 2.94483542e-01  8.91236141e-02 -1.93948522e-...
# 6484  [ 0.32404217  0.17202039  0.01095749 -0.288463...
# 6485  [ 0.1968945   0.23594557 -0.0112275  -0.438629...
#
#                                     infersent_embedding
# 0     [ 0.00746889 -0.03935728  0.14250019 ...  0.03...
# 1     [ 0.00746889 -0.0651099   0.13684836 ...  0.03...
# 2     [ 0.00746889 -0.01138695  0.1386209  ...  0.03...
# 3     [ 0.00746889  0.01478766  0.13787052 ...  0.03...
# 4     [ 0.00746889  0.1031021   0.05695953 ...  0.02...
# ...                                                 ...
# 6481  [ 0.00746889 -0.03935728  0.14250019 ...  0.02...
# 6482  [ 0.00746889  0.09774677  0.04487773 ...  0.02...
# 6483  [ 7.4688918e-03  2.9498454e-02  5.0322294e-02 ...
# 6484  [ 0.00746889  0.05110065  0.17894739 ... -0.00...
# 6485  [ 0.00746889  0.0570666   0.18063141 ...  0.06...
#
# [6486 rows x 7 columns]

# %%
train_df['infersent_embedding'] = train_df.apply(lambda row: get_sentence_embedding(row,infersent,False), axis=1)
train_df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                                                   premise  \
# 9604.0  If Emily passes her driving test, her best fri...
# 9605.0  It's not the case that if Emily passes her dri...
# 9606.0  Sam believes that if Emily passes her driving ...
# 9607.0  Is it true that if Emily passes her driving te...
# 9608.0  If Scarlett finishes her work early, her husba...
# ...                                                   ...
# NaN     If Emily passes her driving test, her best fri...
# NaN     It's not the case that if Scarlett finishes he...
# NaN     Sam believes that if Chloe finishes his work e...
# NaN     Is it true that if Ryan passes his driving tes...
# NaN     If Ryan passes his driving test, his parents w...
#
#                            hypothesis gold_label              type  \
# 9604.0       Emily has a best friend.          E  type5_possessive
# 9605.0       Emily has a best friend.          E  type5_possessive
# 9606.0       Emily has a best friend.          E  type5_possessive
# 9607.0       Emily has a best friend.          E  type5_possessive
# 9608.0        Scarlett has a husband.          E  type5_possessive
# ...                               ...        ...               ...
# NaN               Emily has a sister.          N  type5_possessive
# NaN     Scarlett has a sister-in-law.          N  type5_possessive
# NaN                 Chloe has a boss.          N  type5_possessive
# NaN                Ryan has siblings.          N  type5_possessive
# NaN        Ryan does not have parents          C  type5_possessive
#
#                                       infersent_embedding
# 9604.0  [0.007468892, -0.03935728, 0.14250019, 0.00283...
# 9605.0  [0.007468892, -0.0651099, 0.13684836, -0.00299...
# 9606.0  [0.007468892, -0.011386951, 0.1386209, -0.0106...
# 9607.0  [0.007468892, 0.014787662, 0.13787052, -0.0069...
# 9608.0  [0.007468892, 0.103102095, 0.05695953, 0.00852...
# ...                                                   ...
# NaN     [0.007468892, -0.03935728, 0.14250019, 0.00283...
# NaN     [0.007468892, 0.097746775, 0.044877727, -0.002...
# NaN     [0.007468892, 0.029498454, 0.050322294, -0.026...
# NaN     [0.007468892, 0.051100645, 0.17894739, -0.0069...
# NaN     [0.007468892, 0.0570666, 0.18063141, 0.0028372...
#
# [6486 rows x 5 columns]

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
valid_df['infersent_embedding'] = valid_df.apply(lambda row: get_sentence_embedding(row,infersent,False), axis=1)
valid_df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                                                   premise  \
# 9600.0  If Jessica attends the conference, her colleag...
# 9601.0  It's not the case that if Jessica attends the ...
# 9602.0  Sam believes that if Jessica attends the confe...
# 9603.0  Is it true that if Jessica attends the confere...
# 9620.0  If Mia's car breaks down, her coworker will gi...
# ...                                                   ...
# NaN     If Margaret graduates from college, her parent...
# NaN     It's not the case that if Margaret graduates f...
# NaN     Sam believes that if Margaret graduates from c...
# NaN     Is it true that if Margaret graduates from col...
# NaN     If Margaret graduates from college, her parent...
#
#                                                hypothesis gold_label  \
# 9600.0                           Jessica has a colleague.          E
# 9601.0                           Jessica has a colleague.          E
# 9602.0                           Jessica has a colleague.          E
# 9603.0                           Jessica has a colleague.          E
# 9620.0                                Mia has a coworker.          E
# ...                                                   ...        ...
# NaN                                Margaret has siblings.          N
# NaN                                Margaret has siblings.          N
# NaN                                Margaret has siblings.          N
# NaN                                Margaret has siblings.          N
# NaN     Margaret has graduated from college, but her p...          C
#
#                     type                                infersent_embedding
# 9600.0  type5_possessive  [0.007468892, -0.03935728, 0.07611349, 0.00283...
# 9601.0  type5_possessive  [0.007468892, -0.06974457, 0.06695202, -0.0029...
# 9602.0  type5_possessive  [0.007468892, -0.011386951, 0.07092403, -0.026...
# 9603.0  type5_possessive  [0.007468892, 0.014787662, 0.0689139, -0.00699...
# 9620.0  type5_possessive  [0.007468892, -0.03935728, 0.07314407, 0.00283...
# ...                  ...                                                ...
# NaN     type5_possessive  [0.007468892, 0.025551178, 0.099181, 0.0028372...
# NaN     type5_possessive  [0.007468892, 0.019712852, 0.09699498, -0.0029...
# NaN     type5_possessive  [0.007468892, 0.019370425, 0.09709465, -0.0260...
# NaN     type5_possessive  [0.007468892, 0.020212928, 0.097212546, -0.006...
# NaN     type5_possessive  [0.007468892, 0.025551178, 0.099181, 0.0028372...
#
# [2348 rows x 5 columns]

# %%
test_df['infersent_embedding'] = test_df.apply(lambda row: get_sentence_embedding(row,infersent,False), axis=1)
test_df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                                                   premise  \
# 9616.0  If Charlotte passes her driving test, her pare...
# 9617.0  It's not the case that if Charlotte passes her...
# 9618.0  Sam believes that if Charlotte passes her driv...
# 9619.0  Is it true that if Charlotte passes her drivin...
# 9628.0  If Lily takes the train to the city, her frien...
# ...                                                   ...
# NaN     If Sophia decides to attend the concert, his b...
# NaN     It's not the case that if Sophia decides to at...
# NaN     Sam believes that if Sophia decides to attend ...
# NaN     Is it true that if Sophia decides to attend th...
# NaN     If Sophia decides to attend the concert, his b...
#
#                                                hypothesis gold_label  \
# 9616.0                             Charlotte has parents.          E
# 9617.0                             Charlotte has parents.          E
# 9618.0                             Charlotte has parents.          E
# 9619.0                             Charlotte has parents.          E
# 9628.0                                 Lily has a friend.          E
# ...                                                   ...        ...
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN     Sophia has decided to attend the concert, but ...          C
#
#                     type                                infersent_embedding
# 9616.0  type5_possessive  [0.007468892, 0.021648515, 0.06960781, 0.00283...
# 9617.0  type5_possessive  [0.007468892, 0.017604705, 0.06544004, -0.0029...
# 9618.0  type5_possessive  [0.007468892, 0.017084634, 0.066421606, -0.026...
# 9619.0  type5_possessive  [0.007468892, 0.01786328, 0.06608839, -0.00699...
# 9628.0  type5_possessive  [0.007468892, -0.03935728, 0.09391705, 0.00283...
# ...                  ...                                                ...
# NaN     type5_possessive  [0.007468892, 0.026252104, 0.13633686, 0.00379...
# NaN     type5_possessive  [0.007468892, 0.023293741, 0.13292643, -0.0029...
# NaN     type5_possessive  [0.007468892, 0.023073498, 0.13371763, -0.0260...
# NaN     type5_possessive  [0.007468892, 0.023527713, 0.13347696, -0.0069...
# NaN     type5_possessive  [0.007468892, 0.026252104, 0.13633686, 0.00379...
#
# [2367 rows x 5 columns]

# %%
valid_df.to_csv('valid_infersent_df.csv')

# %%
test_df.to_csv('test_infersent_df.csv')

# %%
train_df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                                                   premise  \
# 9604.0  If Emily passes her driving test, her best fri...
# 9605.0  It's not the case that if Emily passes her dri...
# 9606.0  Sam believes that if Emily passes her driving ...
# 9607.0  Is it true that if Emily passes her driving te...
# 9608.0  If Scarlett finishes her work early, her husba...
# ...                                                   ...
# NaN     If Emily passes her driving test, her best fri...
# NaN     It's not the case that if Scarlett finishes he...
# NaN     Sam believes that if Chloe finishes his work e...
# NaN     Is it true that if Ryan passes his driving tes...
# NaN     If Ryan passes his driving test, his parents w...
#
#                            hypothesis gold_label              type  \
# 9604.0       Emily has a best friend.          E  type5_possessive
# 9605.0       Emily has a best friend.          E  type5_possessive
# 9606.0       Emily has a best friend.          E  type5_possessive
# 9607.0       Emily has a best friend.          E  type5_possessive
# 9608.0        Scarlett has a husband.          E  type5_possessive
# ...                               ...        ...               ...
# NaN               Emily has a sister.          N  type5_possessive
# NaN     Scarlett has a sister-in-law.          N  type5_possessive
# NaN                 Chloe has a boss.          N  type5_possessive
# NaN                Ryan has siblings.          N  type5_possessive
# NaN        Ryan does not have parents          C  type5_possessive
#
#                                           glove_embedding  \
# 9604.0  [0.069057465, 0.38865215, -0.1840484, -0.21967...
# 9605.0  [0.21939042, 0.25260824, -0.14202265, -0.12464...
# 9606.0  [0.15687543, 0.30070943, -0.10854657, -0.17401...
# 9607.0  [0.18888807, 0.30759755, -0.12772465, -0.16519...
# 9608.0  [0.24861601, 0.38644078, -0.21351472, -0.27863...
# ...                                                   ...
# NaN     [0.069057465, 0.38865215, -0.1840484, -0.21967...
# NaN     [0.36916268, 0.22392519, -0.1532617, -0.144940...
# NaN     [0.29448354, 0.089123614, -0.019394852, -0.256...
# NaN     [0.32404217, 0.17202039, 0.010957494, -0.28846...
# NaN     [0.1968945, 0.23594557, -0.011227503, -0.43862...
#
#                                       infersent_embedding
# 9604.0  [0.007468892, -0.03935728, 0.14250019, 0.00283...
# 9605.0  [0.007468892, -0.0651099, 0.13684836, -0.00299...
# 9606.0  [0.007468892, -0.011386951, 0.1386209, -0.0106...
# 9607.0  [0.007468892, 0.014787662, 0.13787052, -0.0069...
# 9608.0  [0.007468892, 0.103102095, 0.05695953, 0.00852...
# ...                                                   ...
# NaN     [0.007468892, -0.03935728, 0.14250019, 0.00283...
# NaN     [0.007468892, 0.097746775, 0.044877727, -0.002...
# NaN     [0.007468892, 0.029498454, 0.050322294, -0.026...
# NaN     [0.007468892, 0.051100645, 0.17894739, -0.0069...
# NaN     [0.007468892, 0.0570666, 0.18063141, 0.0028372...
#
# [6486 rows x 6 columns]

# %%
train_df.to_csv('new_train_data_embeddings.csv')

# %%
valid_df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                                                   premise  \
# 9600.0  If Jessica attends the conference, her colleag...
# 9601.0  It's not the case that if Jessica attends the ...
# 9602.0  Sam believes that if Jessica attends the confe...
# 9603.0  Is it true that if Jessica attends the confere...
# 9620.0  If Mia's car breaks down, her coworker will gi...
# ...                                                   ...
# NaN     If Margaret graduates from college, her parent...
# NaN     It's not the case that if Margaret graduates f...
# NaN     Sam believes that if Margaret graduates from c...
# NaN     Is it true that if Margaret graduates from col...
# NaN     If Margaret graduates from college, her parent...
#
#                                                hypothesis gold_label  \
# 9600.0                           Jessica has a colleague.          E
# 9601.0                           Jessica has a colleague.          E
# 9602.0                           Jessica has a colleague.          E
# 9603.0                           Jessica has a colleague.          E
# 9620.0                                Mia has a coworker.          E
# ...                                                   ...        ...
# NaN                                Margaret has siblings.          N
# NaN                                Margaret has siblings.          N
# NaN                                Margaret has siblings.          N
# NaN                                Margaret has siblings.          N
# NaN     Margaret has graduated from college, but her p...          C
#
#                     type
# 9600.0  type5_possessive
# 9601.0  type5_possessive
# 9602.0  type5_possessive
# 9603.0  type5_possessive
# 9620.0  type5_possessive
# ...                  ...
# NaN     type5_possessive
# NaN     type5_possessive
# NaN     type5_possessive
# NaN     type5_possessive
# NaN     type5_possessive
#
# [2348 rows x 4 columns]

# %% [markdown]
# ## ClassificationNet

# %%
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
import torch
from sklearn.model_selection import train_test_split

# %%
X_train = np.array(train_df['infersent_embedding'])
y_train = np.array(train_df['gold_label'].map({'E': 0,'N': 1,'C':2}))

# %%
X_train = np.array(train_df['infersent_embedding'])
X_val = np.array(valid_df['infersent_embedding'])

# %%
y_val = np.array(valid_df['gold_label'].map({'E': 0,'N': 1,'C':2})) 
y_train = np.array(train_df['gold_label'].map({'E': 0,'N': 1,'C':2}))

# %%
X_train
# Out:
# array([array([ 0.00746889, -0.03935728,  0.14250019, ...,  0.03999854,
#                0.01024261, -0.0138564 ], dtype=float32)               ,
#        array([ 0.00746889, -0.0651099 ,  0.13684836, ...,  0.03999854,
#                0.01024261, -0.0138564 ], dtype=float32)               ,
#        array([ 0.00746889, -0.01138695,  0.1386209 , ...,  0.03999854,
#                0.01024261, -0.0138564 ], dtype=float32)               ,
#        ...,
#        array([ 7.4688918e-03,  2.9498454e-02,  5.0322294e-02, ...,
#                2.5216669e-02,  9.5851654e-03, -4.1406725e-05], dtype=float32),
#        array([ 0.00746889,  0.05110065,  0.17894739, ..., -0.00326828,
#               -0.04434213, -0.0138564 ], dtype=float32)               ,
#        array([ 0.00746889,  0.0570666 ,  0.18063141, ...,  0.06649899,
#               -0.0487872 , -0.01836736], dtype=float32)               ],
#       dtype=object)

# %%
X_val
# Out:
# array([array([ 0.00746889, -0.03935728,  0.07611349, ...,  0.03946821,
#               -0.01182941, -0.0138564 ], dtype=float32)               ,
#        array([ 0.00746889, -0.06974457,  0.06695202, ...,  0.03946821,
#               -0.01182941, -0.0138564 ], dtype=float32)               ,
#        array([ 0.00746889, -0.01138695,  0.07092403, ...,  0.03946821,
#               -0.01182941, -0.0138564 ], dtype=float32)               ,
#        ...,
#        array([ 0.00746889,  0.01937043,  0.09709465, ..., -0.00326828,
#               -0.04434213, -0.0138564 ], dtype=float32)               ,
#        array([ 0.00746889,  0.02021293,  0.09721255, ..., -0.00326828,
#               -0.04434213, -0.0138564 ], dtype=float32)               ,
#        array([ 0.00746889,  0.02555118,  0.099181  , ...,  0.06418673,
#                0.07047024, -0.01553987], dtype=float32)               ],
#       dtype=object)

# %%
# DataLoader

class EmbeddingsDataset(Dataset):
    def __init__(self, embeddings, labels):
        self.embeddings = embeddings
        self.labels = labels

    def __len__(self):
        return len(self.embeddings)

    def __getitem__(self, idx):
        embedding = self.embeddings[idx]
        label = self.labels[idx]
        return torch.tensor(embedding, dtype=torch.float32), torch.tensor(label, dtype=torch.long)

# %%
train_dataset = EmbeddingsDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)

# %%
# Create the dataset
train_dataset = EmbeddingsDataset(X_train, y_train)
val_dataset = EmbeddingsDataset(X_val, y_val)

# Create the DataLoader
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=8, shuffle=True)
print(len(train_loader))
print(len(val_loader))
# Out:
# 811
# 294

# %%
for batch in train_loader:
    # Extract the data and labels
    data, labels = batch
    # Print the first example in the batch
    print("Data:", data[0])
    print("Label:", labels[0])
    
    break
# Out:
# Data: tensor([ 0.0075,  0.0148,  0.0906,  ...,  0.0257,  0.0520, -0.0028])
# Label: tensor(1)

# %%
config = {
    'nonlinear_fc': 0,
    'fc_dim': 512,
    'n_classes': 3,
    'enc_lstm_dim': 2048,
    'encoder_type': 'InferSent',
    'dpout_fc': 0.5,
    'bsize': 64,
    'word_emb_dim': 8192,
    'enc_lstm_dim': 2048,
    'pool_type': 'max',
    'dpout_model': 0.0,
    'n_enc_layers': 1,
    'version': 2  # Use version 2 for fastText
}

# %%
glove_config = {
    'n_classes': 3,
    'fc_dim': 512, # fully connected dimensions
    'word_emb_dim': 100, # size of embeddings
    'dpout_fc': 0.5,
}

# %%
# modified 
class ClassificationNet(nn.Module):
    def __init__(self, config):
        super(ClassificationNet, self).__init__()
        
        self.n_classes = config['n_classes']
        self.fc_dim = config['fc_dim']
        self.embedding_dim = config['word_emb_dim']
        
        self.classifier = nn.Sequential(
            nn.Linear(self.embedding_dim, self.fc_dim),
            nn.ReLU(),
            nn.Dropout(p=config['dpout_fc']),
            nn.Linear(self.fc_dim, self.n_classes),
        )

    def forward(self, embeddings):
        output = self.classifier(embeddings)
        return output

# %%
model = ClassificationNet(config)
if torch.cuda.is_available():
    model.cuda()

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
num_epochs = 50

# %%
def train_model(model): 
    if torch.cuda.is_available():
        model.cuda()
    
    for epoch in range(num_epochs):
        model.train()  # Set the model to training mode
    
        running_loss = 0.0
        correct_predictions = 0
        total_samples = 0
    
        for s1_batch, labels in train_loader:  # train_loader is a DataLoader for training data
            if torch.cuda.is_available():
                s1_batch = s1_batch.cuda()
                labels = labels.cuda()
    
            # Zero the parameter gradients
            optimizer.zero_grad()

            # Forward pass
            outputs = model(s1_batch)
            loss = criterion(outputs, labels)
    
            # Backward pass and optimize
            loss.backward()
            optimizer.step()
    
            # Accumulate loss
            running_loss += loss.item()
    
            # Compute accuracy
            _, predicted = torch.max(outputs.data, 1)
            total_samples += labels.size(0)
            correct_predictions += (predicted == labels).sum().item()
    
        accuracy = 100 * correct_predictions / total_samples
        print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {running_loss / len(train_loader):.4f}, Accuracy: {accuracy:.2f}%')
    
        # # Validation phase
        model.eval()  # Set the model to evaluation mode
        val_running_loss = 0.0
        val_correct_predictions = 0
        val_total_samples = 0
        
        with torch.no_grad():  # No need to calculate gradients during validation
            for s1_batch, labels in val_loader:  # val_loader is a DataLoader for validation data
                if torch.cuda.is_available():
                    s1_batch = s1_batch.cuda()
                    labels = labels.cuda()
    
                # Forward pass
                outputs = model(s1_batch)
                loss = criterion(outputs, labels)
    
                # Accumulate loss
                val_running_loss += loss.item()
    
                # Compute accuracy
                _, predicted = torch.max(outputs.data, 1)
                val_total_samples += labels.size(0)
                val_correct_predictions += (predicted == labels).sum().item()
    
        val_accuracy = 100 * val_correct_predictions / val_total_samples
        print(f'Epoch [{epoch + 1}/{num_epochs}], Validation Loss: {val_running_loss / len(val_loader):.4f}, Validation Accuracy: {val_accuracy:.2f}%')

# %%
train_model(model)
# Out:
# Epoch [1/50], Loss: 0.0069, Accuracy: 99.86%
# Epoch [1/50], Validation Loss: 1.2147, Validation Accuracy: 95.14%
# Epoch [2/50], Loss: 0.0079, Accuracy: 99.81%
# Epoch [2/50], Validation Loss: 1.2203, Validation Accuracy: 95.61%
# Epoch [3/50], Loss: 0.0086, Accuracy: 99.85%
# Epoch [3/50], Validation Loss: 1.2474, Validation Accuracy: 94.97%
# Epoch [4/50], Loss: 0.0135, Accuracy: 99.68%
# Epoch [4/50], Validation Loss: 1.1499, Validation Accuracy: 95.70%
# Epoch [5/50], Loss: 0.0099, Accuracy: 99.80%
# Epoch [5/50], Validation Loss: 1.3140, Validation Accuracy: 95.14%
# Epoch [6/50], Loss: 0.0078, Accuracy: 99.85%
# Epoch [6/50], Validation Loss: 1.2673, Validation Accuracy: 95.61%
# Epoch [7/50], Loss: 0.0174, Accuracy: 99.74%
# Epoch [7/50], Validation Loss: 1.3779, Validation Accuracy: 95.61%
# Epoch [8/50], Loss: 0.0139, Accuracy: 99.78%
# Epoch [8/50], Validation Loss: 1.2477, Validation Accuracy: 96.00%
# Epoch [9/50], Loss: 0.0227, Accuracy: 99.68%
# Epoch [9/50], Validation Loss: 1.3400, Validation Accuracy: 95.06%
# Epoch [10/50], Loss: 0.0089, Accuracy: 99.85%
# Epoch [10/50], Validation Loss: 1.2983, Validation Accuracy: 95.49%
# Epoch [11/50], Loss: 0.0059, Accuracy: 99.83%
# Epoch [11/50], Validation Loss: 1.4584, Validation Accuracy: 95.19%
# Epoch [12/50], Loss: 0.0150, Accuracy: 99.86%
# Epoch [12/50], Validation Loss: 1.3852, Validation Accuracy: 95.19%
# Epoch [13/50], Loss: 0.0081, Accuracy: 99.92%
# Epoch [13/50], Validation Loss: 1.4165, Validation Accuracy: 95.44%
# Epoch [14/50], Loss: 0.0003, Accuracy: 99.97%
# Epoch [14/50], Validation Loss: 1.6137, Validation Accuracy: 94.68%
# Epoch [15/50], Loss: 0.0112, Accuracy: 99.85%
# Epoch [15/50], Validation Loss: 1.6037, Validation Accuracy: 94.93%
# Epoch [16/50], Loss: 0.0226, Accuracy: 99.66%
# Epoch [16/50], Validation Loss: 1.4908, Validation Accuracy: 95.44%
# Epoch [17/50], Loss: 0.0021, Accuracy: 99.94%
# Epoch [17/50], Validation Loss: 1.4013, Validation Accuracy: 95.14%
# Epoch [18/50], Loss: 0.0002, Accuracy: 100.00%
# Epoch [18/50], Validation Loss: 1.3765, Validation Accuracy: 95.32%
# Epoch [19/50], Loss: 0.0025, Accuracy: 99.94%
# Epoch [19/50], Validation Loss: 1.4890, Validation Accuracy: 95.10%
# Epoch [20/50], Loss: 0.0190, Accuracy: 99.66%
# Epoch [20/50], Validation Loss: 1.4746, Validation Accuracy: 95.49%
# Epoch [21/50], Loss: 0.0046, Accuracy: 99.89%
# Epoch [21/50], Validation Loss: 1.7597, Validation Accuracy: 95.40%
# Epoch [22/50], Loss: 0.0083, Accuracy: 99.89%
# Epoch [22/50], Validation Loss: 1.6910, Validation Accuracy: 94.93%
# Epoch [23/50], Loss: 0.0098, Accuracy: 99.89%
# Epoch [23/50], Validation Loss: 1.5899, Validation Accuracy: 95.10%
# Epoch [24/50], Loss: 0.0105, Accuracy: 99.83%
# Epoch [24/50], Validation Loss: 1.6773, Validation Accuracy: 95.40%
# Epoch [25/50], Loss: 0.0147, Accuracy: 99.78%
# Epoch [25/50], Validation Loss: 1.4269, Validation Accuracy: 95.36%
# Epoch [26/50], Loss: 0.0152, Accuracy: 99.81%
# Epoch [26/50], Validation Loss: 1.4635, Validation Accuracy: 95.61%
# Epoch [27/50], Loss: 0.0106, Accuracy: 99.83%
# Epoch [27/50], Validation Loss: 1.8949, Validation Accuracy: 95.53%
# Epoch [28/50], Loss: 0.0094, Accuracy: 99.88%
# Epoch [28/50], Validation Loss: 1.7171, Validation Accuracy: 95.36%
# Epoch [29/50], Loss: 0.0128, Accuracy: 99.88%
# Epoch [29/50], Validation Loss: 1.5317, Validation Accuracy: 95.74%
# Epoch [30/50], Loss: 0.0277, Accuracy: 99.69%
# Epoch [30/50], Validation Loss: 1.3968, Validation Accuracy: 95.87%
# Epoch [31/50], Loss: 0.0135, Accuracy: 99.86%
# Epoch [31/50], Validation Loss: 1.5970, Validation Accuracy: 94.59%
# Epoch [32/50], Loss: 0.0109, Accuracy: 99.91%
# Epoch [32/50], Validation Loss: 1.6535, Validation Accuracy: 95.66%
# Epoch [33/50], Loss: 0.0164, Accuracy: 99.85%
# Epoch [33/50], Validation Loss: 1.6495, Validation Accuracy: 95.32%
# Epoch [34/50], Loss: 0.0156, Accuracy: 99.80%
# Epoch [34/50], Validation Loss: 1.6977, Validation Accuracy: 95.57%
# Epoch [35/50], Loss: 0.0030, Accuracy: 99.94%
# Epoch [35/50], Validation Loss: 1.7390, Validation Accuracy: 95.40%
# Epoch [36/50], Loss: 0.0017, Accuracy: 99.97%
# Epoch [36/50], Validation Loss: 1.6280, Validation Accuracy: 95.74%
# Epoch [37/50], Loss: 0.0234, Accuracy: 99.69%
# Epoch [37/50], Validation Loss: 2.2635, Validation Accuracy: 94.68%
# Epoch [38/50], Loss: 0.0096, Accuracy: 99.88%
# Epoch [38/50], Validation Loss: 1.7722, Validation Accuracy: 94.97%
# Epoch [39/50], Loss: 0.0160, Accuracy: 99.83%
# Epoch [39/50], Validation Loss: 2.0634, Validation Accuracy: 95.23%
# Epoch [40/50], Loss: 0.0152, Accuracy: 99.81%
# Epoch [40/50], Validation Loss: 1.8110, Validation Accuracy: 95.61%
# Epoch [41/50], Loss: 0.0014, Accuracy: 99.97%
# Epoch [41/50], Validation Loss: 1.7059, Validation Accuracy: 95.23%
# Epoch [42/50], Loss: 0.0055, Accuracy: 99.89%
# Epoch [42/50], Validation Loss: 1.9202, Validation Accuracy: 95.40%
# Epoch [43/50], Loss: 0.0075, Accuracy: 99.89%
# Epoch [43/50], Validation Loss: 1.9713, Validation Accuracy: 95.44%
# Epoch [44/50], Loss: 0.0124, Accuracy: 99.81%
# Epoch [44/50], Validation Loss: 2.0469, Validation Accuracy: 95.23%
# Epoch [45/50], Loss: 0.0077, Accuracy: 99.85%
# Epoch [45/50], Validation Loss: 1.6252, Validation Accuracy: 95.36%
# Epoch [46/50], Loss: 0.0038, Accuracy: 99.97%
# Epoch [46/50], Validation Loss: 1.6856, Validation Accuracy: 95.57%
# Epoch [47/50], Loss: 0.0217, Accuracy: 99.77%
# Epoch [47/50], Validation Loss: 2.0884, Validation Accuracy: 95.91%
# Epoch [48/50], Loss: 0.0247, Accuracy: 99.77%
# Epoch [48/50], Validation Loss: 1.9489, Validation Accuracy: 95.23%
# Epoch [49/50], Loss: 0.0073, Accuracy: 99.92%
# Epoch [49/50], Validation Loss: 1.9042, Validation Accuracy: 94.97%
# Epoch [50/50], Loss: 0.0072, Accuracy: 99.92%
# Epoch [50/50], Validation Loss: 2.1721, Validation Accuracy: 95.36%

# %%
train_model(model)
# Out:
# Epoch [1/50], Loss: 0.1691, Accuracy: 94.00%
# Epoch [2/50], Loss: 0.0568, Accuracy: 98.20%
# Epoch [3/50], Loss: 0.0426, Accuracy: 98.78%
# Epoch [4/50], Loss: 0.0234, Accuracy: 99.29%
# Epoch [5/50], Loss: 0.0290, Accuracy: 98.95%
# Epoch [6/50], Loss: 0.0298, Accuracy: 99.01%
# Epoch [7/50], Loss: 0.0333, Accuracy: 98.97%
# Epoch [8/50], Loss: 0.0212, Accuracy: 99.34%
# Epoch [9/50], Loss: 0.0188, Accuracy: 99.40%
# Epoch [10/50], Loss: 0.0229, Accuracy: 99.34%
# Epoch [11/50], Loss: 0.0222, Accuracy: 99.38%
# Epoch [12/50], Loss: 0.0137, Accuracy: 99.58%
# Epoch [13/50], Loss: 0.0269, Accuracy: 99.28%
# Epoch [14/50], Loss: 0.0158, Accuracy: 99.54%
# Epoch [15/50], Loss: 0.0077, Accuracy: 99.74%
# Epoch [16/50], Loss: 0.0223, Accuracy: 99.44%
# Epoch [17/50], Loss: 0.0148, Accuracy: 99.55%
# Epoch [18/50], Loss: 0.0116, Accuracy: 99.68%
# Epoch [19/50], Loss: 0.0098, Accuracy: 99.69%
# Epoch [20/50], Loss: 0.0134, Accuracy: 99.61%
# Epoch [21/50], Loss: 0.0346, Accuracy: 99.18%
# Epoch [22/50], Loss: 0.0095, Accuracy: 99.71%
# Epoch [23/50], Loss: 0.0065, Accuracy: 99.81%
# Epoch [24/50], Loss: 0.0101, Accuracy: 99.69%
# Epoch [25/50], Loss: 0.0236, Accuracy: 99.38%
# Epoch [26/50], Loss: 0.0125, Accuracy: 99.71%
# Epoch [27/50], Loss: 0.0084, Accuracy: 99.71%
# Epoch [28/50], Loss: 0.0160, Accuracy: 99.60%
# Epoch [29/50], Loss: 0.0125, Accuracy: 99.68%
# Epoch [30/50], Loss: 0.0182, Accuracy: 99.58%
# Epoch [31/50], Loss: 0.0106, Accuracy: 99.71%
# Epoch [32/50], Loss: 0.0094, Accuracy: 99.72%
# Epoch [33/50], Loss: 0.0089, Accuracy: 99.78%
# Epoch [34/50], Loss: 0.0118, Accuracy: 99.81%
# Epoch [35/50], Loss: 0.0208, Accuracy: 99.57%
# Epoch [36/50], Loss: 0.0158, Accuracy: 99.72%
# Epoch [37/50], Loss: 0.0132, Accuracy: 99.68%
# Epoch [38/50], Loss: 0.0151, Accuracy: 99.74%
# Epoch [39/50], Loss: 0.0152, Accuracy: 99.68%
# Epoch [40/50], Loss: 0.0099, Accuracy: 99.77%
# Epoch [41/50], Loss: 0.0173, Accuracy: 99.74%
# Epoch [42/50], Loss: 0.0173, Accuracy: 99.75%
# Epoch [43/50], Loss: 0.0165, Accuracy: 99.72%
# Epoch [44/50], Loss: 0.0012, Accuracy: 99.95%
# Epoch [45/50], Loss: 0.0004, Accuracy: 99.98%
# Epoch [46/50], Loss: 0.0236, Accuracy: 99.55%
# Epoch [47/50], Loss: 0.0058, Accuracy: 99.85%
# Epoch [48/50], Loss: 0.0173, Accuracy: 99.77%
# Epoch [49/50], Loss: 0.0052, Accuracy: 99.86%
# Epoch [50/50], Loss: 0.0152, Accuracy: 99.74%

# %%
train_model(model)
# Out:
# Epoch [1/50], Loss: 0.1629, Accuracy: 94.05%
# Epoch [1/50], Validation Loss: 0.2713, Validation Accuracy: 94.25%
# Epoch [2/50], Loss: 0.0570, Accuracy: 98.44%
# Epoch [2/50], Validation Loss: 0.3791, Validation Accuracy: 92.72%
# Epoch [3/50], Loss: 0.0403, Accuracy: 98.74%
# Epoch [3/50], Validation Loss: 0.3249, Validation Accuracy: 93.40%
# Epoch [4/50], Loss: 0.0322, Accuracy: 98.91%
# Epoch [4/50], Validation Loss: 0.3488, Validation Accuracy: 94.85%
# Epoch [5/50], Loss: 0.0246, Accuracy: 99.17%
# Epoch [5/50], Validation Loss: 0.3429, Validation Accuracy: 95.36%
# Epoch [6/50], Loss: 0.0209, Accuracy: 99.31%
# Epoch [6/50], Validation Loss: 0.3753, Validation Accuracy: 94.72%
# Epoch [7/50], Loss: 0.0264, Accuracy: 99.23%
# Epoch [7/50], Validation Loss: 0.3651, Validation Accuracy: 95.06%
# Epoch [8/50], Loss: 0.0214, Accuracy: 99.29%
# Epoch [8/50], Validation Loss: 0.4217, Validation Accuracy: 94.76%
# Epoch [9/50], Loss: 0.0251, Accuracy: 99.17%
# Epoch [9/50], Validation Loss: 0.4037, Validation Accuracy: 94.93%
# Epoch [10/50], Loss: 0.0114, Accuracy: 99.66%
# Epoch [10/50], Validation Loss: 0.4591, Validation Accuracy: 95.36%
# Epoch [11/50], Loss: 0.0209, Accuracy: 99.48%
# Epoch [11/50], Validation Loss: 0.4871, Validation Accuracy: 95.06%
# Epoch [12/50], Loss: 0.0320, Accuracy: 98.92%
# Epoch [12/50], Validation Loss: 0.6402, Validation Accuracy: 93.70%
# Epoch [13/50], Loss: 0.0112, Accuracy: 99.60%
# Epoch [13/50], Validation Loss: 0.5746, Validation Accuracy: 94.08%
# Epoch [14/50], Loss: 0.0105, Accuracy: 99.60%
# Epoch [14/50], Validation Loss: 0.5193, Validation Accuracy: 95.32%
# Epoch [15/50], Loss: 0.0155, Accuracy: 99.58%
# Epoch [15/50], Validation Loss: 0.5670, Validation Accuracy: 95.19%
# Epoch [16/50], Loss: 0.0235, Accuracy: 99.26%
# Epoch [16/50], Validation Loss: 0.6874, Validation Accuracy: 94.89%
# Epoch [17/50], Loss: 0.0131, Accuracy: 99.61%
# Epoch [17/50], Validation Loss: 0.5429, Validation Accuracy: 95.74%
# Epoch [18/50], Loss: 0.0131, Accuracy: 99.61%
# Epoch [18/50], Validation Loss: 0.5727, Validation Accuracy: 95.32%
# Epoch [19/50], Loss: 0.0150, Accuracy: 99.54%
# Epoch [19/50], Validation Loss: 0.8066, Validation Accuracy: 94.72%
# Epoch [20/50], Loss: 0.0114, Accuracy: 99.61%
# Epoch [20/50], Validation Loss: 0.6485, Validation Accuracy: 95.02%
# Epoch [21/50], Loss: 0.0129, Accuracy: 99.54%
# Epoch [21/50], Validation Loss: 0.7489, Validation Accuracy: 94.76%
# Epoch [22/50], Loss: 0.0139, Accuracy: 99.72%
# Epoch [22/50], Validation Loss: 0.7166, Validation Accuracy: 94.76%
# Epoch [23/50], Loss: 0.0233, Accuracy: 99.49%
# Epoch [23/50], Validation Loss: 0.9283, Validation Accuracy: 94.46%
# Epoch [24/50], Loss: 0.0186, Accuracy: 99.51%
# Epoch [24/50], Validation Loss: 0.7026, Validation Accuracy: 95.10%
# Epoch [25/50], Loss: 0.0043, Accuracy: 99.88%
# Epoch [25/50], Validation Loss: 0.6718, Validation Accuracy: 95.57%
# Epoch [26/50], Loss: 0.0046, Accuracy: 99.86%
# Epoch [26/50], Validation Loss: 0.7199, Validation Accuracy: 95.53%
# Epoch [27/50], Loss: 0.0177, Accuracy: 99.65%
# Epoch [27/50], Validation Loss: 0.7898, Validation Accuracy: 95.02%
# Epoch [28/50], Loss: 0.0090, Accuracy: 99.77%
# Epoch [28/50], Validation Loss: 0.7712, Validation Accuracy: 95.27%
# Epoch [29/50], Loss: 0.0113, Accuracy: 99.68%
# Epoch [29/50], Validation Loss: 1.0266, Validation Accuracy: 95.02%
# Epoch [30/50], Loss: 0.0159, Accuracy: 99.66%
# Epoch [30/50], Validation Loss: 0.8297, Validation Accuracy: 95.53%
# Epoch [31/50], Loss: 0.0152, Accuracy: 99.68%
# Epoch [31/50], Validation Loss: 0.8818, Validation Accuracy: 95.27%
# Epoch [32/50], Loss: 0.0079, Accuracy: 99.75%
# Epoch [32/50], Validation Loss: 1.0933, Validation Accuracy: 94.21%
# Epoch [33/50], Loss: 0.0166, Accuracy: 99.57%
# Epoch [33/50], Validation Loss: 1.1217, Validation Accuracy: 94.85%
# Epoch [34/50], Loss: 0.0149, Accuracy: 99.71%
# Epoch [34/50], Validation Loss: 1.1847, Validation Accuracy: 94.63%
# Epoch [35/50], Loss: 0.0063, Accuracy: 99.78%
# Epoch [35/50], Validation Loss: 0.9306, Validation Accuracy: 94.97%
# Epoch [36/50], Loss: 0.0166, Accuracy: 99.74%
# Epoch [36/50], Validation Loss: 0.8985, Validation Accuracy: 95.23%
# Epoch [37/50], Loss: 0.0053, Accuracy: 99.83%
# Epoch [37/50], Validation Loss: 1.0301, Validation Accuracy: 95.02%
# Epoch [38/50], Loss: 0.0145, Accuracy: 99.74%
# Epoch [38/50], Validation Loss: 1.1327, Validation Accuracy: 95.57%
# Epoch [39/50], Loss: 0.0061, Accuracy: 99.77%
# Epoch [39/50], Validation Loss: 1.1612, Validation Accuracy: 94.38%
# Epoch [40/50], Loss: 0.0198, Accuracy: 99.74%
# Epoch [40/50], Validation Loss: 1.2853, Validation Accuracy: 94.89%
# Epoch [41/50], Loss: 0.0127, Accuracy: 99.80%
# Epoch [41/50], Validation Loss: 1.2105, Validation Accuracy: 94.93%
# Epoch [42/50], Loss: 0.0057, Accuracy: 99.83%
# Epoch [42/50], Validation Loss: 1.1162, Validation Accuracy: 95.19%
# Epoch [43/50], Loss: 0.0140, Accuracy: 99.81%
# Epoch [43/50], Validation Loss: 1.2884, Validation Accuracy: 94.29%
# Epoch [44/50], Loss: 0.0099, Accuracy: 99.77%
# Epoch [44/50], Validation Loss: 1.1664, Validation Accuracy: 94.80%
# Epoch [45/50], Loss: 0.0075, Accuracy: 99.91%
# Epoch [45/50], Validation Loss: 1.1641, Validation Accuracy: 95.19%
# Epoch [46/50], Loss: 0.0222, Accuracy: 99.61%
# Epoch [46/50], Validation Loss: 1.1327, Validation Accuracy: 95.57%
# Epoch [47/50], Loss: 0.0080, Accuracy: 99.86%
# Epoch [47/50], Validation Loss: 1.2617, Validation Accuracy: 95.10%
# Epoch [48/50], Loss: 0.0125, Accuracy: 99.78%
# Epoch [48/50], Validation Loss: 1.1348, Validation Accuracy: 95.49%
# Epoch [49/50], Loss: 0.0047, Accuracy: 99.89%
# Epoch [49/50], Validation Loss: 0.9806, Validation Accuracy: 95.95%
# Epoch [50/50], Loss: 0.0116, Accuracy: 99.80%
# Epoch [50/50], Validation Loss: 1.2664, Validation Accuracy: 94.21%

# %%
# evaluating on test set
test_embeddings = list(test_df['infersent_embedding'])
test_embeddings[:3]
# Out:
# [array([ 0.00746889,  0.02164852,  0.06960781, ...,  0.00071831,
#         -0.04434213, -0.0138564 ], dtype=float32),
#  array([ 0.00746889,  0.0176047 ,  0.06544004, ...,  0.00071831,
#         -0.04434213, -0.0138564 ], dtype=float32),
#  array([ 0.00746889,  0.01708463,  0.06642161, ...,  0.00071831,
#         -0.04434213, -0.0138564 ], dtype=float32)]

# %%
if torch.cuda.is_available():
    print("GPU is available!")
    device = torch.device("cuda")
else:
    print("GPU is not available, using CPU")
    device = torch.device("cpu")
# Out:
# GPU is available!

# %%
test_embeddings = torch.tensor(test_embeddings).to(device)

# %%
with torch.no_grad():
    outputs = model(test_embeddings)
predictions = torch.argmax(outputs, dim=1)
predictions
# Out:
# tensor([0, 0, 0,  ..., 0, 0, 2], device='cuda:0')

# %%
test_df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                                                   premise  \
# 9616.0  If Charlotte passes her driving test, her pare...
# 9617.0  It's not the case that if Charlotte passes her...
# 9618.0  Sam believes that if Charlotte passes her driv...
# 9619.0  Is it true that if Charlotte passes her drivin...
# 9628.0  If Lily takes the train to the city, her frien...
# ...                                                   ...
# NaN     If Sophia decides to attend the concert, his b...
# NaN     It's not the case that if Sophia decides to at...
# NaN     Sam believes that if Sophia decides to attend ...
# NaN     Is it true that if Sophia decides to attend th...
# NaN     If Sophia decides to attend the concert, his b...
#
#                                                hypothesis gold_label  \
# 9616.0                             Charlotte has parents.          E
# 9617.0                             Charlotte has parents.          E
# 9618.0                             Charlotte has parents.          E
# 9619.0                             Charlotte has parents.          E
# 9628.0                                 Lily has a friend.          E
# ...                                                   ...        ...
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN     Sophia has decided to attend the concert, but ...          C
#
#                     type                                infersent_embedding  \
# 9616.0  type5_possessive  [0.007468892, 0.021648515, 0.06960781, 0.00283...
# 9617.0  type5_possessive  [0.007468892, 0.017604705, 0.06544004, -0.0029...
# 9618.0  type5_possessive  [0.007468892, 0.017084634, 0.066421606, -0.026...
# 9619.0  type5_possessive  [0.007468892, 0.01786328, 0.06608839, -0.00699...
# 9628.0  type5_possessive  [0.007468892, -0.03935728, 0.09391705, 0.00283...
# ...                  ...                                                ...
# NaN     type5_possessive  [0.007468892, 0.026252104, 0.13633686, 0.00379...
# NaN     type5_possessive  [0.007468892, 0.023293741, 0.13292643, -0.0029...
# NaN     type5_possessive  [0.007468892, 0.023073498, 0.13371763, -0.0260...
# NaN     type5_possessive  [0.007468892, 0.023527713, 0.13347696, -0.0069...
# NaN     type5_possessive  [0.007468892, 0.026252104, 0.13633686, 0.00379...
#
#        predicted_label
# 9616.0               E
# 9617.0               E
# 9618.0               E
# 9619.0               E
# 9628.0               E
# ...                ...
# NaN                  E
# NaN                  E
# NaN                  E
# NaN                  E
# NaN                  C
#
# [2367 rows x 6 columns]

# %%
test_df['predicted_label'] = predictions.cpu()
test_df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                                                   premise  \
# 9616.0  If Charlotte passes her driving test, her pare...
# 9617.0  It's not the case that if Charlotte passes her...
# 9618.0  Sam believes that if Charlotte passes her driv...
# 9619.0  Is it true that if Charlotte passes her drivin...
# 9628.0  If Lily takes the train to the city, her frien...
# ...                                                   ...
# NaN     If Sophia decides to attend the concert, his b...
# NaN     It's not the case that if Sophia decides to at...
# NaN     Sam believes that if Sophia decides to attend ...
# NaN     Is it true that if Sophia decides to attend th...
# NaN     If Sophia decides to attend the concert, his b...
#
#                                                hypothesis gold_label  \
# 9616.0                             Charlotte has parents.          E
# 9617.0                             Charlotte has parents.          E
# 9618.0                             Charlotte has parents.          E
# 9619.0                             Charlotte has parents.          E
# 9628.0                                 Lily has a friend.          E
# ...                                                   ...        ...
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN     Sophia has decided to attend the concert, but ...          C
#
#                     type                                infersent_embedding  \
# 9616.0  type5_possessive  [0.007468892, 0.021648515, 0.06960781, 0.00283...
# 9617.0  type5_possessive  [0.007468892, 0.017604705, 0.06544004, -0.0029...
# 9618.0  type5_possessive  [0.007468892, 0.017084634, 0.066421606, -0.026...
# 9619.0  type5_possessive  [0.007468892, 0.01786328, 0.06608839, -0.00699...
# 9628.0  type5_possessive  [0.007468892, -0.03935728, 0.09391705, 0.00283...
# ...                  ...                                                ...
# NaN     type5_possessive  [0.007468892, 0.026252104, 0.13633686, 0.00379...
# NaN     type5_possessive  [0.007468892, 0.023293741, 0.13292643, -0.0029...
# NaN     type5_possessive  [0.007468892, 0.023073498, 0.13371763, -0.0260...
# NaN     type5_possessive  [0.007468892, 0.023527713, 0.13347696, -0.0069...
# NaN     type5_possessive  [0.007468892, 0.026252104, 0.13633686, 0.00379...
#
#         predicted_label
# 9616.0                0
# 9617.0                0
# 9618.0                0
# 9619.0                0
# 9628.0                0
# ...                 ...
# NaN                   0
# NaN                   0
# NaN                   0
# NaN                   0
# NaN                   2
#
# [2367 rows x 6 columns]

# %%
test_df['predicted_label'] = test_df['predicted_label'].map({0: 'E',1: 'N', 2: 'C'})
test_df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                                                   premise  \
# 9616.0  If Charlotte passes her driving test, her pare...
# 9617.0  It's not the case that if Charlotte passes her...
# 9618.0  Sam believes that if Charlotte passes her driv...
# 9619.0  Is it true that if Charlotte passes her drivin...
# 9628.0  If Lily takes the train to the city, her frien...
# ...                                                   ...
# NaN     If Sophia decides to attend the concert, his b...
# NaN     It's not the case that if Sophia decides to at...
# NaN     Sam believes that if Sophia decides to attend ...
# NaN     Is it true that if Sophia decides to attend th...
# NaN     If Sophia decides to attend the concert, his b...
#
#                                                hypothesis gold_label  \
# 9616.0                             Charlotte has parents.          E
# 9617.0                             Charlotte has parents.          E
# 9618.0                             Charlotte has parents.          E
# 9619.0                             Charlotte has parents.          E
# 9628.0                                 Lily has a friend.          E
# ...                                                   ...        ...
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN     Sophia has decided to attend the concert, but ...          C
#
#                     type                                infersent_embedding  \
# 9616.0  type5_possessive  [0.007468892, 0.021648515, 0.06960781, 0.00283...
# 9617.0  type5_possessive  [0.007468892, 0.017604705, 0.06544004, -0.0029...
# 9618.0  type5_possessive  [0.007468892, 0.017084634, 0.066421606, -0.026...
# 9619.0  type5_possessive  [0.007468892, 0.01786328, 0.06608839, -0.00699...
# 9628.0  type5_possessive  [0.007468892, -0.03935728, 0.09391705, 0.00283...
# ...                  ...                                                ...
# NaN     type5_possessive  [0.007468892, 0.026252104, 0.13633686, 0.00379...
# NaN     type5_possessive  [0.007468892, 0.023293741, 0.13292643, -0.0029...
# NaN     type5_possessive  [0.007468892, 0.023073498, 0.13371763, -0.0260...
# NaN     type5_possessive  [0.007468892, 0.023527713, 0.13347696, -0.0069...
# NaN     type5_possessive  [0.007468892, 0.026252104, 0.13633686, 0.00379...
#
#        predicted_label
# 9616.0               E
# 9617.0               E
# 9618.0               E
# 9619.0               E
# 9628.0               E
# ...                ...
# NaN                  E
# NaN                  E
# NaN                  E
# NaN                  E
# NaN                  C
#
# [2367 rows x 6 columns]

# %%
test_df.to_csv('Exp5_InferSent_results_run3.csv')

# %%
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Create the testing confusion matrix
cm = confusion_matrix(test_df['gold_label'], test_df['predicted_label'])

# Visualize the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d",cmap="Blues")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %%
report_dict = classification_report(test_df['gold_label'], test_df['predicted_label'], output_dict=True)
report_df = pd.DataFrame(report_dict).transpose() 
report_df.columns.name = 'label'
report_df
# Out:
# label         precision    recall  f1-score     support
# C              0.935802  0.986979  0.960710   768.00000
# E              0.966480  0.961111  0.963788   720.00000
# N              0.960761  0.919226  0.939535   879.00000
# accuracy       0.953950  0.953950  0.953950     0.95395
# macro avg      0.954348  0.955772  0.954678  2367.00000
# weighted avg   0.954403  0.953950  0.953783  2367.00000

# %%
def compute_metrics_by_type(group):
    predictions = group['gold_label']
    labels = group['predicted_label']
    acc = np.mean(predictions == labels)
    precision = precision_score(labels, predictions,average="weighted")
    recall = recall_score(labels, predictions,average="weighted")
    f1 = f1_score(labels, predictions,average="weighted")
    return pd.Series({'accuracy': round(acc,2), 'precision': round(precision,2), 'recall': round(recall,2), 'f1_score': round(f1,2)})

# %%
metrics_by_type = test_df.groupby('type').apply(compute_metrics_by_type).reset_index()
metrics_by_type.columns.name = 'ID'
metrics_by_type
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# <ipython-input-72-5261ab470594>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   metrics_by_type = test_df.groupby('type').apply(compute_metrics_by_type).reset_index()
# ID              type  accuracy  precision  recall  f1_score
# 0        type1_again      0.94       0.94    0.94      0.94
# 1   type1_possessive      0.93       0.93    0.93      0.93
# 2        type2_again      0.98       0.96    0.98      0.97
# 3   type2_possessive      0.96       0.96    0.96      0.96
# 4        type3_again      0.91       0.98    0.91      0.94
# 5   type3_possessive      1.00       1.00    1.00      1.00
# 6   type4_possessive      0.95       0.96    0.95      0.95
# 7        type5_again      0.94       0.93    0.94      0.94
# 8   type5_possessive      0.97       1.00    0.97      0.98
