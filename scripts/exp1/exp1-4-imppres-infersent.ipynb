# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import pickle
import gensim.downloader as api
from gensim.models import KeyedVectors

# %% [markdown]
# # Dataset

# %%
train_df = pd.read_csv('/kaggle/input/imppres/imppres.csv',index_col=0)
train_df
# Out:
#                                                  premise  \
# 0      All ten guys that proved to boast were divorcing.
# 1      All ten guys that proved to boast were divorcing.
# 2      All ten guys that proved to boast were divorcing.
# 3      All ten guys that proved to boast weren't divo...
# 4      All ten guys that proved to boast weren't divo...
# ...                                                  ...
# 17095  If the actors do conceal where that mall shock...
# 17096  The actors didn't conceal where that mall shoc...
# 17097  Did the actors conceal where that mall shocks ...
# 17098  The actors might have concealed where that mal...
# 17099  If the actors do conceal where that mall shock...
#
#                                               hypothesis  gold_label
# 0       There are exactly ten guys that proved to boast.           0
# 1      There are exactly eleven guys that proved to b...           2
# 2      There are exactly ten senators that proved to ...           1
# 3       There are exactly ten guys that proved to boast.           0
# 4      There are exactly eleven guys that proved to b...           2
# ...                                                  ...         ...
# 17095                               Travel shocks Janet.           1
# 17096  The actors do conceal where that mall shocks J...           2
# 17097  The actors do conceal where that mall shocks J...           1
# 17098  The actors do conceal where that mall shocks J...           1
# 17099  The actors do conceal where that mall shocks J...           1
#
# [17100 rows x 3 columns]

# %%
train_orig_df = pd.read_csv('/kaggle/input/imppres/imppres.csv',index_col=0)
train_orig_df
# Out:
#                                                  premise  \
# 0      All ten guys that proved to boast were divorcing.
# 1      All ten guys that proved to boast were divorcing.
# 2      All ten guys that proved to boast were divorcing.
# 3      All ten guys that proved to boast weren't divo...
# 4      All ten guys that proved to boast weren't divo...
# ...                                                  ...
# 17095  If the actors do conceal where that mall shock...
# 17096  The actors didn't conceal where that mall shoc...
# 17097  Did the actors conceal where that mall shocks ...
# 17098  The actors might have concealed where that mal...
# 17099  If the actors do conceal where that mall shock...
#
#                                               hypothesis  gold_label
# 0       There are exactly ten guys that proved to boast.           0
# 1      There are exactly eleven guys that proved to b...           2
# 2      There are exactly ten senators that proved to ...           1
# 3       There are exactly ten guys that proved to boast.           0
# 4      There are exactly eleven guys that proved to b...           2
# ...                                                  ...         ...
# 17095                               Travel shocks Janet.           1
# 17096  The actors do conceal where that mall shocks J...           2
# 17097  The actors do conceal where that mall shocks J...           1
# 17098  The actors do conceal where that mall shocks J...           1
# 17099  The actors do conceal where that mall shocks J...           1
#
# [17100 rows x 3 columns]

# %%
valid_df = pd.read_csv('/kaggle/input/nli-data/new_valid_all.csv',index_col=0)
valid_df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                                                   premise  \
# 9600.0  If Jessica attends the conference, her colleag...
# 9601.0  It's not the case that if Jessica attends the ...
# 9602.0  Sam believes that if Jessica attends the confe...
# 9603.0  Is it true that if Jessica attends the confere...
# 9620.0  If Mia's car breaks down, her coworker will gi...
# ...                                                   ...
# NaN     If Margaret graduates from college, her parent...
# NaN     It's not the case that if Margaret graduates f...
# NaN     Sam believes that if Margaret graduates from c...
# NaN     Is it true that if Margaret graduates from col...
# NaN     If Margaret graduates from college, her parent...
#
#                                                hypothesis gold_label  \
# 9600.0                           Jessica has a colleague.          E
# 9601.0                           Jessica has a colleague.          E
# 9602.0                           Jessica has a colleague.          E
# 9603.0                           Jessica has a colleague.          E
# 9620.0                                Mia has a coworker.          E
# ...                                                   ...        ...
# NaN                                Margaret has siblings.          N
# NaN                                Margaret has siblings.          N
# NaN                                Margaret has siblings.          N
# NaN                                Margaret has siblings.          N
# NaN     Margaret has graduated from college, but her p...          C
#
#                     type
# 9600.0  type5_possessive
# 9601.0  type5_possessive
# 9602.0  type5_possessive
# 9603.0  type5_possessive
# 9620.0  type5_possessive
# ...                  ...
# NaN     type5_possessive
# NaN     type5_possessive
# NaN     type5_possessive
# NaN     type5_possessive
# NaN     type5_possessive
#
# [2348 rows x 4 columns]

# %%
valid_orig_df = pd.read_csv('/kaggle/input/nli-data/new_valid_all.csv',index_col=0)
valid_orig_df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                                                   premise  \
# 9600.0  If Jessica attends the conference, her colleag...
# 9601.0  It's not the case that if Jessica attends the ...
# 9602.0  Sam believes that if Jessica attends the confe...
# 9603.0  Is it true that if Jessica attends the confere...
# 9620.0  If Mia's car breaks down, her coworker will gi...
# ...                                                   ...
# NaN     If Margaret graduates from college, her parent...
# NaN     It's not the case that if Margaret graduates f...
# NaN     Sam believes that if Margaret graduates from c...
# NaN     Is it true that if Margaret graduates from col...
# NaN     If Margaret graduates from college, her parent...
#
#                                                hypothesis gold_label  \
# 9600.0                           Jessica has a colleague.          E
# 9601.0                           Jessica has a colleague.          E
# 9602.0                           Jessica has a colleague.          E
# 9603.0                           Jessica has a colleague.          E
# 9620.0                                Mia has a coworker.          E
# ...                                                   ...        ...
# NaN                                Margaret has siblings.          N
# NaN                                Margaret has siblings.          N
# NaN                                Margaret has siblings.          N
# NaN                                Margaret has siblings.          N
# NaN     Margaret has graduated from college, but her p...          C
#
#                     type
# 9600.0  type5_possessive
# 9601.0  type5_possessive
# 9602.0  type5_possessive
# 9603.0  type5_possessive
# 9620.0  type5_possessive
# ...                  ...
# NaN     type5_possessive
# NaN     type5_possessive
# NaN     type5_possessive
# NaN     type5_possessive
# NaN     type5_possessive
#
# [2348 rows x 4 columns]

# %%
test_df = pd.read_csv('/kaggle/input/nli-data/new_test_all.csv',index_col=0)
test_df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                                                   premise  \
# 9616.0  If Charlotte passes her driving test, her pare...
# 9617.0  It's not the case that if Charlotte passes her...
# 9618.0  Sam believes that if Charlotte passes her driv...
# 9619.0  Is it true that if Charlotte passes her drivin...
# 9628.0  If Lily takes the train to the city, her frien...
# ...                                                   ...
# NaN     If Sophia decides to attend the concert, his b...
# NaN     It's not the case that if Sophia decides to at...
# NaN     Sam believes that if Sophia decides to attend ...
# NaN     Is it true that if Sophia decides to attend th...
# NaN     If Sophia decides to attend the concert, his b...
#
#                                                hypothesis gold_label  \
# 9616.0                             Charlotte has parents.          E
# 9617.0                             Charlotte has parents.          E
# 9618.0                             Charlotte has parents.          E
# 9619.0                             Charlotte has parents.          E
# 9628.0                                 Lily has a friend.          E
# ...                                                   ...        ...
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN     Sophia has decided to attend the concert, but ...          C
#
#                     type
# 9616.0  type5_possessive
# 9617.0  type5_possessive
# 9618.0  type5_possessive
# 9619.0  type5_possessive
# 9628.0  type5_possessive
# ...                  ...
# NaN     type5_possessive
# NaN     type5_possessive
# NaN     type5_possessive
# NaN     type5_possessive
# NaN     type5_possessive
#
# [2367 rows x 4 columns]

# %%
train_df['premise'].isna().sum()
# Out:
# 0

# %%
train_df['hypothesis'].isna().sum()
# Out:
# 0

# %%
train_df[train_df['hypothesis'].isna()]
# Out:
# Empty DataFrame
# Columns: [premise, hypothesis, gold_label]
# Index: []

# %%
train_df.loc[train_df['hypothesis'].isna(), 'hypothesis'] = "Martin has incited a response before"

# %%
train_df[train_df['hypothesis'].isna()]
# Out:
# Empty DataFrame
# Columns: [premise, hypothesis, gold_label]
# Index: []

# %%
train_df['gold_label'].value_counts()
# Out:
# gold_label
# 1    7200
# 2    5400
# 0    4500
# Name: count, dtype: int64

# %% [markdown]
# # InferSent

# %%
import sys

# %%
sys.path.append('/kaggle/input/infersent')

# %%
from models import InferSent
import torch

# %%
params_model = {
    'bsize': 64,
    'word_emb_dim': 300,
    'enc_lstm_dim': 2048,
    'pool_type': 'max',
    'dpout_model': 0.0,
    'n_enc_layers': 1,
    'version': 2  # Use version 2 for fastText
}

# %%
infersent = InferSent(params_model)
infersent.load_state_dict(torch.load('/kaggle/input/infersent/infersent2.pkl'))
infersent.set_w2v_path('/kaggle/input/infersent/crawl-300d-2M.vec/crawl-300d-2M.vec')
# Out:
# <ipython-input-17-6d0716483458>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   infersent.load_state_dict(torch.load('/kaggle/input/infersent/infersent2.pkl'))

# %%
premises = train_df['premise'].tolist()
hypotheses = train_df['hypothesis'].tolist()
all_sentences = premises + hypotheses
len(all_sentences)
# Out:
# 34200

# %%
infersent.build_vocab(all_sentences, tokenize=True)
# Out:
# Found 1537(/1537) words with w2v vectors
# Vocab size : 1537

# %%
train_df['infersent_embedding'] = train_df.apply(lambda row: get_sentence_embedding(row,infersent,False), axis=1)
train_df
# Out:
#                                                  premise  \
# 0      All ten guys that proved to boast were divorcing.
# 1      All ten guys that proved to boast were divorcing.
# 2      All ten guys that proved to boast were divorcing.
# 3      All ten guys that proved to boast weren't divo...
# 4      All ten guys that proved to boast weren't divo...
# ...                                                  ...
# 17095  If the actors do conceal where that mall shock...
# 17096  The actors didn't conceal where that mall shoc...
# 17097  Did the actors conceal where that mall shocks ...
# 17098  The actors might have concealed where that mal...
# 17099  If the actors do conceal where that mall shock...
#
#                                               hypothesis  gold_label  \
# 0       There are exactly ten guys that proved to boast.           0
# 1      There are exactly eleven guys that proved to b...           2
# 2      There are exactly ten senators that proved to ...           1
# 3       There are exactly ten guys that proved to boast.           0
# 4      There are exactly eleven guys that proved to b...           2
# ...                                                  ...         ...
# 17095                               Travel shocks Janet.           1
# 17096  The actors do conceal where that mall shocks J...           2
# 17097  The actors do conceal where that mall shocks J...           1
# 17098  The actors do conceal where that mall shocks J...           1
# 17099  The actors do conceal where that mall shocks J...           1
#
#                                      infersent_embedding
# 0      [0.007468891, 0.24664591, 0.020370156, 0.00143...
# 1      [0.007468891, 0.24664591, 0.020370156, 0.00143...
# 2      [0.007468891, 0.24664591, 0.020370156, 0.00143...
# 3      [0.007468892, 0.24664588, 0.020370148, 0.00143...
# 4      [0.007468892, 0.24664588, 0.020370148, 0.00143...
# ...                                                  ...
# 17095  [0.007468892, -0.016496586, 0.09977109, 0.0028...
# 17096  [0.007468892, 0.030513393, 0.047009096, -0.014...
# 17097  [0.007468891, -0.004921443, 0.065494575, -0.00...
# 17098  [0.007468892, -0.02727963, 0.06733012, -0.0146...
# 17099  [0.007468892, -0.016496586, 0.09977109, 0.0028...
#
# [17100 rows x 4 columns]

# %%
valid_df['infersent_embedding'] = valid_df.apply(lambda row: get_sentence_embedding(row,infersent,False), axis=1)
valid_df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                                                   premise  \
# 9600.0  If Jessica attends the conference, her colleag...
# 9601.0  It's not the case that if Jessica attends the ...
# 9602.0  Sam believes that if Jessica attends the confe...
# 9603.0  Is it true that if Jessica attends the confere...
# 9620.0  If Mia's car breaks down, her coworker will gi...
# ...                                                   ...
# NaN     If Margaret graduates from college, her parent...
# NaN     It's not the case that if Margaret graduates f...
# NaN     Sam believes that if Margaret graduates from c...
# NaN     Is it true that if Margaret graduates from col...
# NaN     If Margaret graduates from college, her parent...
#
#                                                hypothesis gold_label  \
# 9600.0                           Jessica has a colleague.          E
# 9601.0                           Jessica has a colleague.          E
# 9602.0                           Jessica has a colleague.          E
# 9603.0                           Jessica has a colleague.          E
# 9620.0                                Mia has a coworker.          E
# ...                                                   ...        ...
# NaN                                Margaret has siblings.          N
# NaN                                Margaret has siblings.          N
# NaN                                Margaret has siblings.          N
# NaN                                Margaret has siblings.          N
# NaN     Margaret has graduated from college, but her p...          C
#
#                     type                                infersent_embedding
# 9600.0  type5_possessive  [0.007468891, -0.03935728, 0.04375006, 0.00283...
# 9601.0  type5_possessive  [0.007468892, -0.06898636, 0.033369403, -0.002...
# 9602.0  type5_possessive  [0.007468891, -0.069927536, 0.06408549, -0.005...
# 9603.0  type5_possessive  [0.007468892, -0.05717079, 0.053329557, -0.006...
# 9620.0  type5_possessive  [0.007468891, -0.03935728, -0.016383925, 0.002...
# ...                  ...                                                ...
# NaN     type5_possessive  [0.007468891, -0.03935728, 0.0052857124, 0.002...
# NaN     type5_possessive  [0.007468892, -0.07111349, -0.01884494, -0.002...
# NaN     type5_possessive  [0.007468891, -0.081679136, 0.056406762, -0.00...
# NaN     type5_possessive  [0.007468891, -0.057170793, 0.026870165, -0.00...
# NaN     type5_possessive  [0.007468891, -0.03935728, 0.0052857124, 0.002...
#
# [2348 rows x 5 columns]

# %%
test_df['infersent_embedding'] = test_df.apply(lambda row: get_sentence_embedding(row,infersent,False), axis=1)
test_df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                                                   premise  \
# 9616.0  If Charlotte passes her driving test, her pare...
# 9617.0  It's not the case that if Charlotte passes her...
# 9618.0  Sam believes that if Charlotte passes her driv...
# 9619.0  Is it true that if Charlotte passes her drivin...
# 9628.0  If Lily takes the train to the city, her frien...
# ...                                                   ...
# NaN     If Sophia decides to attend the concert, his b...
# NaN     It's not the case that if Sophia decides to at...
# NaN     Sam believes that if Sophia decides to attend ...
# NaN     Is it true that if Sophia decides to attend th...
# NaN     If Sophia decides to attend the concert, his b...
#
#                                                hypothesis gold_label  \
# 9616.0                             Charlotte has parents.          E
# 9617.0                             Charlotte has parents.          E
# 9618.0                             Charlotte has parents.          E
# 9619.0                             Charlotte has parents.          E
# 9628.0                                 Lily has a friend.          E
# ...                                                   ...        ...
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN     Sophia has decided to attend the concert, but ...          C
#
#                     type                                infersent_embedding
# 9616.0  type5_possessive  [0.007468891, -0.03935728, 0.035805665, 0.0028...
# 9617.0  type5_possessive  [0.007468892, -0.06682748, 0.024539622, -0.002...
# 9618.0  type5_possessive  [0.007468891, -0.06450726, 0.06022661, -0.0028...
# 9619.0  type5_possessive  [0.007468891, -0.057170793, 0.050273046, -0.00...
# 9628.0  type5_possessive  [0.007468892, -0.03935728, 0.06870508, 0.00283...
# ...                  ...                                                ...
# NaN     type5_possessive  [0.007468891, -0.03935728, 0.053975556, 0.0028...
# NaN     type5_possessive  [0.007468892, -0.06207959, 0.045018643, -0.002...
# NaN     type5_possessive  [0.007468891, -0.060360007, 0.074209735, -0.00...
# NaN     type5_possessive  [0.007468891, -0.057170793, 0.06461144, -0.006...
# NaN     type5_possessive  [0.007468891, -0.03935728, 0.053975556, 0.0028...
#
# [2367 rows x 5 columns]

# %%
train_df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                                                   premise  \
# 9604.0  If Emily passes her driving test, her best fri...
# 9605.0  It's not the case that if Emily passes her dri...
# 9606.0  Sam believes that if Emily passes her driving ...
# 9607.0  Is it true that if Emily passes her driving te...
# 9608.0  If Scarlett finishes her work early, her husba...
# ...                                                   ...
# NaN     If Emily passes her driving test, her best fri...
# NaN     It's not the case that if Scarlett finishes he...
# NaN     Sam believes that if Chloe finishes his work e...
# NaN     Is it true that if Ryan passes his driving tes...
# NaN     If Ryan passes his driving test, his parents w...
#
#                            hypothesis gold_label              type  \
# 9604.0       Emily has a best friend.          E  type5_possessive
# 9605.0       Emily has a best friend.          E  type5_possessive
# 9606.0       Emily has a best friend.          E  type5_possessive
# 9607.0       Emily has a best friend.          E  type5_possessive
# 9608.0        Scarlett has a husband.          E  type5_possessive
# ...                               ...        ...               ...
# NaN               Emily has a sister.          N  type5_possessive
# NaN     Scarlett has a sister-in-law.          N  type5_possessive
# NaN                 Chloe has a boss.          N  type5_possessive
# NaN                Ryan has siblings.          N  type5_possessive
# NaN        Ryan does not have parents          C  type5_possessive
#
#                                           glove_embedding  \
# 9604.0  [0.069057465, 0.38865215, -0.1840484, -0.21967...
# 9605.0  [0.21939042, 0.25260824, -0.14202265, -0.12464...
# 9606.0  [0.15687543, 0.30070943, -0.10854657, -0.17401...
# 9607.0  [0.18888807, 0.30759755, -0.12772465, -0.16519...
# 9608.0  [0.24861601, 0.38644078, -0.21351472, -0.27863...
# ...                                                   ...
# NaN     [0.069057465, 0.38865215, -0.1840484, -0.21967...
# NaN     [0.36916268, 0.22392519, -0.1532617, -0.144940...
# NaN     [0.29448354, 0.089123614, -0.019394852, -0.256...
# NaN     [0.32404217, 0.17202039, 0.010957494, -0.28846...
# NaN     [0.1968945, 0.23594557, -0.011227503, -0.43862...
#
#                                       infersent_embedding
# 9604.0  [0.007468892, -0.03935728, 0.14250019, 0.00283...
# 9605.0  [0.007468892, -0.0651099, 0.13684836, -0.00299...
# 9606.0  [0.007468892, -0.011386951, 0.1386209, -0.0106...
# 9607.0  [0.007468892, 0.014787662, 0.13787052, -0.0069...
# 9608.0  [0.007468892, 0.103102095, 0.05695953, 0.00852...
# ...                                                   ...
# NaN     [0.007468892, -0.03935728, 0.14250019, 0.00283...
# NaN     [0.007468892, 0.097746775, 0.044877727, -0.002...
# NaN     [0.007468892, 0.029498454, 0.050322294, -0.026...
# NaN     [0.007468892, 0.051100645, 0.17894739, -0.0069...
# NaN     [0.007468892, 0.0570666, 0.18063141, 0.0028372...
#
# [6486 rows x 6 columns]

# %%
train_df.to_csv('new_train_data_embeddings.csv')

# %%
valid_df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                                                   premise  \
# 9600.0  If Jessica attends the conference, her colleag...
# 9601.0  It's not the case that if Jessica attends the ...
# 9602.0  Sam believes that if Jessica attends the confe...
# 9603.0  Is it true that if Jessica attends the confere...
# 9620.0  If Mia's car breaks down, her coworker will gi...
# ...                                                   ...
# NaN     If Margaret graduates from college, her parent...
# NaN     It's not the case that if Margaret graduates f...
# NaN     Sam believes that if Margaret graduates from c...
# NaN     Is it true that if Margaret graduates from col...
# NaN     If Margaret graduates from college, her parent...
#
#                                                hypothesis gold_label  \
# 9600.0                           Jessica has a colleague.          E
# 9601.0                           Jessica has a colleague.          E
# 9602.0                           Jessica has a colleague.          E
# 9603.0                           Jessica has a colleague.          E
# 9620.0                                Mia has a coworker.          E
# ...                                                   ...        ...
# NaN                                Margaret has siblings.          N
# NaN                                Margaret has siblings.          N
# NaN                                Margaret has siblings.          N
# NaN                                Margaret has siblings.          N
# NaN     Margaret has graduated from college, but her p...          C
#
#                     type
# 9600.0  type5_possessive
# 9601.0  type5_possessive
# 9602.0  type5_possessive
# 9603.0  type5_possessive
# 9620.0  type5_possessive
# ...                  ...
# NaN     type5_possessive
# NaN     type5_possessive
# NaN     type5_possessive
# NaN     type5_possessive
# NaN     type5_possessive
#
# [2348 rows x 4 columns]

# %% [markdown]
# ## ClassificationNet

# %%
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
import torch
from sklearn.model_selection import train_test_split

# %%
X_train = np.array(train_df['infersent_embedding'])
y_train = np.array(train_orig_df['gold_label'])

# %%
X_val = np.array(valid_df['infersent_embedding'])
y_val = np.array(valid_orig_df['gold_label'].map({'E': 0,'N': 1,'C':2}))

# %%
X_train
# Out:
# array([array([0.00746889, 0.24664591, 0.02037016, ..., 0.04569286, 0.04756356,
#               0.01045527], dtype=float32)                                     ,
#        array([0.00746889, 0.24664591, 0.02037016, ..., 0.03934213, 0.04025663,
#               0.01045527], dtype=float32)                                     ,
#        array([0.00746889, 0.24664591, 0.02037016, ..., 0.04008486, 0.07071328,
#               0.01045527], dtype=float32)                                     ,
#        ...,
#        array([ 0.00746889, -0.00492144,  0.06549457, ..., -0.00093462,
#                0.04372195, -0.01384092], dtype=float32)               ,
#        array([ 0.00746889, -0.02727963,  0.06733012, ..., -0.00093462,
#                0.04372195, -0.01384092], dtype=float32)               ,
#        array([ 0.00746889, -0.01649659,  0.09977109, ..., -0.00093462,
#                0.04372195, -0.01384092], dtype=float32)               ],
#       dtype=object)

# %%
y_train
# Out:
# array([0, 2, 1, ..., 1, 1, 1])

# %%
X_val
# Out:
# array([array([ 0.00746889, -0.03935728,  0.04375006, ...,  0.03946821,
#               -0.01182941, -0.0138564 ], dtype=float32)               ,
#        array([ 0.00746889, -0.06898636,  0.0333694 , ...,  0.03946821,
#               -0.01182941, -0.0138564 ], dtype=float32)               ,
#        array([ 0.00746889, -0.06992754,  0.06408549, ...,  0.03946821,
#               -0.01182941, -0.0138564 ], dtype=float32)               ,
#        ...,
#        array([ 0.00746889, -0.08167914,  0.05640676, ...,  0.01252648,
#               -0.04434213, -0.0138564 ], dtype=float32)               ,
#        array([ 0.00746889, -0.05717079,  0.02687017, ...,  0.01252648,
#               -0.04434213, -0.0138564 ], dtype=float32)               ,
#        array([ 0.00746889, -0.03935728,  0.00528571, ...,  0.06506839,
#                0.01867037, -0.01991069], dtype=float32)               ],
#       dtype=object)

# %%
y_val
# Out:
# array([0, 0, 0, ..., 1, 1, 2])

# %%
# DataLoader

class EmbeddingsDataset(Dataset):
    def __init__(self, embeddings, labels):
        self.embeddings = embeddings
        self.labels = labels

    def __len__(self):
        return len(self.embeddings)

    def __getitem__(self, idx):
        embedding = self.embeddings[idx]
        label = self.labels[idx]
        return torch.tensor(embedding, dtype=torch.float32), torch.tensor(label, dtype=torch.long)

# %%
train_dataset = EmbeddingsDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)

# %%
# Create the dataset
train_dataset = EmbeddingsDataset(X_train, y_train)
val_dataset = EmbeddingsDataset(X_val, y_val)

# Create the DataLoader
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=8, shuffle=True)
print(len(train_loader))
print(len(val_loader))
# Out:
# 2138
# 294

# %%
for batch in train_loader:
    # Extract the data and labels
    data, labels = batch
    # Print the first example in the batch
    print("Data:", data[0])
    print("Label:", labels[0])
    
    break
# Out:
# Data: tensor([ 0.0075, -0.0572, -0.0368,  ...,  0.0036, -0.0028, -0.0139])
# Label: tensor(2)

# %%
config = {
    'nonlinear_fc': 0,
    'fc_dim': 512,
    'n_classes': 3,
    'enc_lstm_dim': 2048,
    'encoder_type': 'InferSent',
    'dpout_fc': 0.5,
    'bsize': 64,
    'word_emb_dim': 8192,
    'enc_lstm_dim': 2048,
    'pool_type': 'max',
    'dpout_model': 0.0,
    'n_enc_layers': 1,
    'version': 2  # Use version 2 for fastText
}

# %%
glove_config = {
    'n_classes': 3,
    'fc_dim': 512, # fully connected dimensions
    'word_emb_dim': 100, # size of embeddings
    'dpout_fc': 0.5,
}

# %%
# modified 
class ClassificationNet(nn.Module):
    def __init__(self, config):
        super(ClassificationNet, self).__init__()
        
        self.n_classes = config['n_classes']
        self.fc_dim = config['fc_dim']
        self.embedding_dim = config['word_emb_dim']
        
        self.classifier = nn.Sequential(
            nn.Linear(self.embedding_dim, self.fc_dim),
            nn.ReLU(),
            nn.Dropout(p=config['dpout_fc']),
            nn.Linear(self.fc_dim, self.n_classes),
        )

    def forward(self, embeddings):
        output = self.classifier(embeddings)
        return output

# %%
model = ClassificationNet(config)
if torch.cuda.is_available():
    model.cuda()

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
num_epochs = 50

# %%
def train_model(model): 
    if torch.cuda.is_available():
        model.cuda()
    
    for epoch in range(num_epochs):
        model.train()  # Set the model to training mode
    
        running_loss = 0.0
        correct_predictions = 0
        total_samples = 0
    
        for s1_batch, labels in train_loader:  # train_loader is a DataLoader for training data
            if torch.cuda.is_available():
                s1_batch = s1_batch.cuda()
                labels = labels.cuda()
    
            # Zero the parameter gradients
            optimizer.zero_grad()

            # Forward pass
            outputs = model(s1_batch)
            loss = criterion(outputs, labels)
    
            # Backward pass and optimize
            loss.backward()
            optimizer.step()
    
            # Accumulate loss
            running_loss += loss.item()
    
            # Compute accuracy
            _, predicted = torch.max(outputs.data, 1)
            total_samples += labels.size(0)
            correct_predictions += (predicted == labels).sum().item()
    
        accuracy = 100 * correct_predictions / total_samples
        print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {running_loss / len(train_loader):.4f}, Accuracy: {accuracy:.2f}%')
    
        # Validation phase
        model.eval()  # Set the model to evaluation mode
        val_running_loss = 0.0
        val_correct_predictions = 0
        val_total_samples = 0
        
        with torch.no_grad():  # No need to calculate gradients during validation
            for s1_batch, labels in val_loader:  # val_loader is a DataLoader for validation data
                if torch.cuda.is_available():
                    s1_batch = s1_batch.cuda()
                    labels = labels.cuda()
    
                # Forward pass
                outputs = model(s1_batch)
                loss = criterion(outputs, labels)
    
                # Accumulate loss
                val_running_loss += loss.item()
    
                # Compute accuracy
                _, predicted = torch.max(outputs.data, 1)
                val_total_samples += labels.size(0)
                val_correct_predictions += (predicted == labels).sum().item()
    
        val_accuracy = 100 * val_correct_predictions / val_total_samples
        print(f'Epoch [{epoch + 1}/{num_epochs}], Validation Loss: {val_running_loss / len(val_loader):.4f}, Validation Accuracy: {val_accuracy:.2f}%')

# %%
train_model(model)
# Out:
# Epoch [1/50], Loss: 0.0535, Accuracy: 97.98%
# Epoch [1/50], Validation Loss: 6.0236, Validation Accuracy: 40.33%
# Epoch [2/50], Loss: 0.0529, Accuracy: 97.89%
# Epoch [2/50], Validation Loss: 5.9330, Validation Accuracy: 39.35%
# Epoch [3/50], Loss: 0.0510, Accuracy: 97.94%
# Epoch [3/50], Validation Loss: 5.9056, Validation Accuracy: 41.14%
# Epoch [4/50], Loss: 0.0552, Accuracy: 97.70%
# Epoch [4/50], Validation Loss: 5.6016, Validation Accuracy: 42.16%
# Epoch [5/50], Loss: 0.0503, Accuracy: 97.87%
# Epoch [5/50], Validation Loss: 6.0452, Validation Accuracy: 40.42%
# Epoch [6/50], Loss: 0.0468, Accuracy: 98.06%
# Epoch [6/50], Validation Loss: 6.0706, Validation Accuracy: 45.57%
# Epoch [7/50], Loss: 0.0490, Accuracy: 97.87%
# Epoch [7/50], Validation Loss: 5.5185, Validation Accuracy: 44.76%
# Epoch [8/50], Loss: 0.0509, Accuracy: 97.96%
# Epoch [8/50], Validation Loss: 6.5036, Validation Accuracy: 43.06%
# Epoch [9/50], Loss: 0.0499, Accuracy: 97.91%
# Epoch [9/50], Validation Loss: 5.2275, Validation Accuracy: 46.72%
# Epoch [10/50], Loss: 0.0471, Accuracy: 98.07%
# Epoch [10/50], Validation Loss: 5.9714, Validation Accuracy: 44.85%
# Epoch [11/50], Loss: 0.0436, Accuracy: 98.19%
# Epoch [11/50], Validation Loss: 6.3791, Validation Accuracy: 43.27%
# Epoch [12/50], Loss: 0.0452, Accuracy: 98.14%
# Epoch [12/50], Validation Loss: 6.8459, Validation Accuracy: 43.65%
# Epoch [13/50], Loss: 0.0466, Accuracy: 98.15%
# Epoch [13/50], Validation Loss: 7.1097, Validation Accuracy: 40.46%
# Epoch [48/50], Validation Loss: 6.2104, Validation Accuracy: 45.40%
# Epoch [49/50], Loss: 0.0561, Accuracy: 97.80%
# Epoch [49/50], Validation Loss: 6.5718, Validation Accuracy: 44.17%
# Epoch [50/50], Loss: 0.0551, Accuracy: 97.83%
# Epoch [50/50], Validation Loss: 6.1978, Validation Accuracy: 43.82%

# %%
# evaluating on test set
test_embeddings = list(test_df['infersent_embedding'])
test_embeddings[:3]
# Out:
# [array([ 0.00746889, -0.03935728,  0.03580566, ...,  0.01252648,
#         -0.04434213, -0.0138564 ], dtype=float32),
#  array([ 0.00746889, -0.06682748,  0.02453962, ...,  0.01252648,
#         -0.04434213, -0.0138564 ], dtype=float32),
#  array([ 0.00746889, -0.06450726,  0.06022661, ...,  0.01252648,
#         -0.04434213, -0.0138564 ], dtype=float32)]

# %%
if torch.cuda.is_available():
    print("GPU is available!")
    device = torch.device("cuda")
else:
    print("GPU is not available, using CPU")
    device = torch.device("cpu")
# Out:
# GPU is available!

# %%
test_embeddings = torch.tensor(test_embeddings).to(device)

# %%
with torch.no_grad():
    outputs = model(test_embeddings)
predictions = torch.argmax(outputs, dim=1)
predictions
# Out:
# tensor([1, 1, 1,  ..., 1, 1, 1], device='cuda:0')

# %%
test_df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                                                   premise  \
# 9616.0  If Charlotte passes her driving test, her pare...
# 9617.0  It's not the case that if Charlotte passes her...
# 9618.0  Sam believes that if Charlotte passes her driv...
# 9619.0  Is it true that if Charlotte passes her drivin...
# 9628.0  If Lily takes the train to the city, her frien...
# ...                                                   ...
# NaN     If Sophia decides to attend the concert, his b...
# NaN     It's not the case that if Sophia decides to at...
# NaN     Sam believes that if Sophia decides to attend ...
# NaN     Is it true that if Sophia decides to attend th...
# NaN     If Sophia decides to attend the concert, his b...
#
#                                                hypothesis gold_label  \
# 9616.0                             Charlotte has parents.          E
# 9617.0                             Charlotte has parents.          E
# 9618.0                             Charlotte has parents.          E
# 9619.0                             Charlotte has parents.          E
# 9628.0                                 Lily has a friend.          E
# ...                                                   ...        ...
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN     Sophia has decided to attend the concert, but ...          C
#
#                     type                                infersent_embedding  \
# 9616.0  type5_possessive  [0.007468891, -0.03935728, 0.035805665, 0.0028...
# 9617.0  type5_possessive  [0.007468892, -0.06682748, 0.024539622, -0.002...
# 9618.0  type5_possessive  [0.007468891, -0.06450726, 0.06022661, -0.0028...
# 9619.0  type5_possessive  [0.007468891, -0.057170793, 0.050273046, -0.00...
# 9628.0  type5_possessive  [0.007468892, -0.03935728, 0.06870508, 0.00283...
# ...                  ...                                                ...
# NaN     type5_possessive  [0.007468891, -0.03935728, 0.053975556, 0.0028...
# NaN     type5_possessive  [0.007468892, -0.06207959, 0.045018643, -0.002...
# NaN     type5_possessive  [0.007468891, -0.060360007, 0.074209735, -0.00...
# NaN     type5_possessive  [0.007468891, -0.057170793, 0.06461144, -0.006...
# NaN     type5_possessive  [0.007468891, -0.03935728, 0.053975556, 0.0028...
#
#        predicted_label
# 9616.0               N
# 9617.0               N
# 9618.0               N
# 9619.0               N
# 9628.0               N
# ...                ...
# NaN                  N
# NaN                  E
# NaN                  N
# NaN                  N
# NaN                  N
#
# [2367 rows x 6 columns]

# %%
test_df['predicted_label'] = predictions.cpu()
test_df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                                                   premise  \
# 9616.0  If Charlotte passes her driving test, her pare...
# 9617.0  It's not the case that if Charlotte passes her...
# 9618.0  Sam believes that if Charlotte passes her driv...
# 9619.0  Is it true that if Charlotte passes her drivin...
# 9628.0  If Lily takes the train to the city, her frien...
# ...                                                   ...
# NaN     If Sophia decides to attend the concert, his b...
# NaN     It's not the case that if Sophia decides to at...
# NaN     Sam believes that if Sophia decides to attend ...
# NaN     Is it true that if Sophia decides to attend th...
# NaN     If Sophia decides to attend the concert, his b...
#
#                                                hypothesis gold_label  \
# 9616.0                             Charlotte has parents.          E
# 9617.0                             Charlotte has parents.          E
# 9618.0                             Charlotte has parents.          E
# 9619.0                             Charlotte has parents.          E
# 9628.0                                 Lily has a friend.          E
# ...                                                   ...        ...
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN     Sophia has decided to attend the concert, but ...          C
#
#                     type                                infersent_embedding  \
# 9616.0  type5_possessive  [0.007468891, -0.03935728, 0.035805665, 0.0028...
# 9617.0  type5_possessive  [0.007468892, -0.06682748, 0.024539622, -0.002...
# 9618.0  type5_possessive  [0.007468891, -0.06450726, 0.06022661, -0.0028...
# 9619.0  type5_possessive  [0.007468891, -0.057170793, 0.050273046, -0.00...
# 9628.0  type5_possessive  [0.007468892, -0.03935728, 0.06870508, 0.00283...
# ...                  ...                                                ...
# NaN     type5_possessive  [0.007468891, -0.03935728, 0.053975556, 0.0028...
# NaN     type5_possessive  [0.007468892, -0.06207959, 0.045018643, -0.002...
# NaN     type5_possessive  [0.007468891, -0.060360007, 0.074209735, -0.00...
# NaN     type5_possessive  [0.007468891, -0.057170793, 0.06461144, -0.006...
# NaN     type5_possessive  [0.007468891, -0.03935728, 0.053975556, 0.0028...
#
#         predicted_label
# 9616.0                1
# 9617.0                1
# 9618.0                1
# 9619.0                1
# 9628.0                1
# ...                 ...
# NaN                   1
# NaN                   0
# NaN                   1
# NaN                   1
# NaN                   1
#
# [2367 rows x 6 columns]

# %%
test_df['predicted_label'] = test_df['predicted_label'].map({0: 'E',1: 'N', 2: 'C'})
test_df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                                                   premise  \
# 9616.0  If Charlotte passes her driving test, her pare...
# 9617.0  It's not the case that if Charlotte passes her...
# 9618.0  Sam believes that if Charlotte passes her driv...
# 9619.0  Is it true that if Charlotte passes her drivin...
# 9628.0  If Lily takes the train to the city, her frien...
# ...                                                   ...
# NaN     If Sophia decides to attend the concert, his b...
# NaN     It's not the case that if Sophia decides to at...
# NaN     Sam believes that if Sophia decides to attend ...
# NaN     Is it true that if Sophia decides to attend th...
# NaN     If Sophia decides to attend the concert, his b...
#
#                                                hypothesis gold_label  \
# 9616.0                             Charlotte has parents.          E
# 9617.0                             Charlotte has parents.          E
# 9618.0                             Charlotte has parents.          E
# 9619.0                             Charlotte has parents.          E
# 9628.0                                 Lily has a friend.          E
# ...                                                   ...        ...
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN                            Sophia has a close friend.          N
# NaN     Sophia has decided to attend the concert, but ...          C
#
#                     type                                infersent_embedding  \
# 9616.0  type5_possessive  [0.007468891, -0.03935728, 0.035805665, 0.0028...
# 9617.0  type5_possessive  [0.007468892, -0.06682748, 0.024539622, -0.002...
# 9618.0  type5_possessive  [0.007468891, -0.06450726, 0.06022661, -0.0028...
# 9619.0  type5_possessive  [0.007468891, -0.057170793, 0.050273046, -0.00...
# 9628.0  type5_possessive  [0.007468892, -0.03935728, 0.06870508, 0.00283...
# ...                  ...                                                ...
# NaN     type5_possessive  [0.007468891, -0.03935728, 0.053975556, 0.0028...
# NaN     type5_possessive  [0.007468892, -0.06207959, 0.045018643, -0.002...
# NaN     type5_possessive  [0.007468891, -0.060360007, 0.074209735, -0.00...
# NaN     type5_possessive  [0.007468891, -0.057170793, 0.06461144, -0.006...
# NaN     type5_possessive  [0.007468891, -0.03935728, 0.053975556, 0.0028...
#
#        predicted_label
# 9616.0               N
# 9617.0               N
# 9618.0               N
# 9619.0               N
# 9628.0               N
# ...                ...
# NaN                  N
# NaN                  E
# NaN                  N
# NaN                  N
# NaN                  N
#
# [2367 rows x 6 columns]

# %%
test_df.to_csv('exp4_infersent_results_run3.csv')

# %%
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Create the testing confusion matrix
cm = confusion_matrix(test_df['gold_label'], test_df['predicted_label'])

# Visualize the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d",cmap="Blues")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %%
report_dict = classification_report(test_df['gold_label'], test_df['predicted_label'], output_dict=True)
report_df = pd.DataFrame(report_dict).transpose() 
report_df.columns.name = 'label'
report_df
# Out:
# label         precision    recall  f1-score      support
# C              0.861244  0.468750  0.607083   768.000000
# E              0.376396  0.327778  0.350408   720.000000
# N              0.374433  0.563140  0.449796   879.000000
# accuracy       0.460921  0.460921  0.460921     0.460921
# macro avg      0.537357  0.453223  0.469095  2367.000000
# weighted avg   0.532981  0.460921  0.470597  2367.000000

# %%
def compute_metrics_by_type(group):
    predictions = group['gold_label']
    labels = group['predicted_label']
    acc = np.mean(predictions == labels)
    precision = precision_score(labels, predictions,average="weighted")
    recall = recall_score(labels, predictions,average="weighted")
    f1 = f1_score(labels, predictions,average="weighted")
    return pd.Series({'accuracy': round(acc,2), 'precision': round(precision,2), 'recall': round(recall,2), 'f1_score': round(f1,2)})

# %%
metrics_by_type = test_df.groupby('type').apply(compute_metrics_by_type).reset_index()
metrics_by_type.columns.name = 'ID'
metrics_by_type
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# <ipython-input-105-5261ab470594>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   metrics_by_type = test_df.groupby('type').apply(compute_metrics_by_type).reset_index()
# ID              type  accuracy  precision  recall  f1_score
# 0        type1_again      0.43       0.54    0.43      0.48
# 1   type1_possessive      0.43       0.29    0.43      0.34
# 2        type2_again      0.39       0.49    0.39      0.44
# 3   type2_possessive      0.42       0.29    0.42      0.35
# 4        type3_again      0.30       0.39    0.30      0.32
# 5   type3_possessive      0.51       0.54    0.51      0.50
# 6   type4_possessive      0.68       0.70    0.68      0.69
# 7        type5_again      0.30       0.81    0.30      0.20
# 8   type5_possessive      0.58       0.65    0.58      0.48
